# %%
import numpy as np
import pandas as pd
import os
import codecs
from bs4 import BeautifulSoup as BS
import trafilatura
from tqdm.notebook import tqdm
import warnings
import pickle
from scipy.sparse import hstack, vstack, csr_matrix
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import f1_score
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.model_selection import GroupKFold
from catboost import CatBoostClassifier
import lightgbm
import xgboost
from nltk.corpus import stopwords

warnings.filterwarnings('ignore')

# %% [markdown]
# # Идея 1.
# Добавить фич с помощью контента веб-страниц в .dat-файлах. Распарсим htmlки и нормализуем слова.

# %% [markdown]
# Будем сохранять данные в процессе, так как ноутбук может вылетать.

# %%
def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# Распарсим текст в HTML-ках, чтобы потом получить оттуда фичи.

# %%
datapath = os.path.join("..", "project_data")
test_data = pd.read_csv(os.path.join(datapath, "data", "test_groups.csv"), dtype=np.int16)
train_data = pd.read_csv(os.path.join(datapath, 'data', 'train_groups.csv'), dtype=np.int16)

def parse_features(data, savename): # test or train
    description = {}
    keywords = {}
    texts = {}

    contentpath = os.path.join(datapath, 'content')
    for filename in tqdm(os.listdir(contentpath)):
    #for filename in ['10.dat']:
        doc_id = int(filename.strip('.dat'))
        if doc_id not in data.doc_id.values:
            continue
        try:
            with codecs.open(os.path.join(contentpath, filename), 'r', encoding='utf-8') as f:
                url = f.readline().strip()
                html = f.read()
                #print(html)
                bs = BS(html, 'html.parser')
                meta = bs.find('meta', {'name': 'description'})
                if meta:
                    description[doc_id] = meta.get('content', '')
                meta = bs.find('meta', {'name': 'keywords'})
                if meta:
                    keywords[doc_id] = meta.get('content', '')
                text = trafilatura.extract(html, include_comments=False)
                if text:
                    text = text.replace('\n', ' ')
                    text = text.replace('\t', ' ')
                    text = text.replace('\r', ' ')
                    texts[doc_id] = text
        except UnicodeDecodeError:
            print(f'got unicode error with utf-8 in {filename}')
        except Exception as e:
            print(f'{e} in {filename}')

    data['description'] = data['doc_id'].map(description)
    data['keywords'] = data['doc_id'].map(keywords)
    data['texts'] = data['doc_id'].map(texts)
    
    save_obj(data, savename)

parse_features(train_data, 'train_data')
train_data.head()
# Out:
#   0%|          | 0/28024 [00:00<?, ?it/s]
#    pair_id  group_id  doc_id  target  \
# 0        1         1   15731       0
# 1        2         1   14829       0
# 2        3         1   15764       0
# 3        4         1   17669       0
# 4        5         1   14852       0
#
#                                          description  \
# 0  Замена подшипников ступицы, руководство по рем...
# 1  Ваз 2107 оптом. Продажа, поиск, поставщики и м...
# 2  Продажа запчастей ступица для легковых и грузо...
# 3                                                NaN
# 4  Передняя ступица Нива имеет свои особенности в...
#
#                                             keywords  \
# 0  Замена подшипников ступицы, техническое описан...
# 1  ваз 2107 оптом, Россия, Сочи, цены, предложени...
# 2  Цена, замена, тюнинг, купить, продать, ступица...
# 3                                                NaN
# 4                                                NaN
#
#                                                texts
# 0  Сняв рычаг с болтов, отводим его от поворотног...
# 1  при заказе от 5 шт. при заказе от 10 шт. при з...
# 2  |Ступица задняя левая ВАЗ ЛАДА Калина 2 С ABS|...
# 3  |Номенклатура ||21010 ||Цена | |00000094000000...
# 4  Ступица Нива — как провести ремонт и замену по...

# %% [markdown]
# И добавим заголовки к документам.

# %%
def add_titles(data):  # test or train
    doc_to_title = {}
    with open(os.path.join(datapath, 'data', 'docs_titles.tsv'), encoding='UTF-8') as f:
        for num_line, line in enumerate(f):
            if num_line == 0:
                continue
            titles = line.strip().split('\t', 1)
            doc_id = int(titles[0])
            if len(titles) == 1:
                title = ''
            else:
                title = titles[1]
            doc_to_title[doc_id] = title
    data['titles'] = data['doc_id'].map(doc_to_title)

add_titles(train_data)

# %%
train_data.head()
# Out:
#    pair_id  group_id  doc_id  target  \
# 0        1         1   15731       0
# 1        2         1   14829       0
# 2        3         1   15764       0
# 3        4         1   17669       0
# 4        5         1   14852       0
#
#                                          description  \
# 0  Замена подшипников ступицы, руководство по рем...
# 1  Ваз 2107 оптом. Продажа, поиск, поставщики и м...
# 2  Продажа запчастей ступица для легковых и грузо...
# 3                                                NaN
# 4  Передняя ступица Нива имеет свои особенности в...
#
#                                             keywords  \
# 0  Замена подшипников ступицы, техническое описан...
# 1  ваз 2107 оптом, Россия, Сочи, цены, предложени...
# 2  Цена, замена, тюнинг, купить, продать, ступица...
# 3                                                NaN
# 4                                                NaN
#
#                                                texts  \
# 0  Сняв рычаг с болтов, отводим его от поворотног...
# 1  при заказе от 5 шт. при заказе от 10 шт. при з...
# 2  |Ступица задняя левая ВАЗ ЛАДА Калина 2 С ABS|...
# 3  |Номенклатура ||21010 ||Цена | |00000094000000...
# 4  Ступица Нива — как провести ремонт и замену по...
#
#                                               titles
# 0      ВАЗ 21213 | Замена подшипников ступицы | Нива
# 1  Ваз 2107 оптом в Сочи. Сравнить цены, купить п...
# 2  Купить ступица Лада калина2. Трансмиссия - пер...
# 3                             Классика 21010 - 21074
# 4     Ступица Нива — замена подшипника своими руками

# %%
save_obj(train_data, 'train_data')

# %% [markdown]
# Уберем Nan.

# %%
train_data = train_data.fillna('')
test_data = test_data.fillna('')

# %% [markdown]
# Текст -- это хорошо, но разобьем на слова и приведем к нормальной форме.

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

def normalize_words(text):
    words = text.split()
    res = [morph.parse(word)[0].normal_form for word in words]
    return ' '.join(res)

# %%
def normalize_data(data): # test or train
    data['norm_title'] = data.apply(lambda row: normalize_words(row.titles), axis=1)
    data['norm_keywords'] = data.apply(lambda row: normalize_words(row.keywords), axis=1)
    data['norm_description'] = data.apply(lambda row: normalize_words(row.description), axis=1)
    data['sum_title'] = data.apply(lambda row: row.norm_title + row.norm_description + row.norm_keywords, axis=1)

normalize_data(train_data)

# %%
train_data.head()
# Out:
#    pair_id  group_id  doc_id  target  \
# 0        1         1   15731       0
# 1        2         1   14829       0
# 2        3         1   15764       0
# 3        4         1   17669       0
# 4        5         1   14852       0
#
#                                          description  \
# 0  Замена подшипников ступицы, руководство по рем...
# 1  Ваз 2107 оптом. Продажа, поиск, поставщики и м...
# 2  Продажа запчастей ступица для легковых и грузо...
# 3
# 4  Передняя ступица Нива имеет свои особенности в...
#
#                                             keywords  \
# 0  Замена подшипников ступицы, техническое описан...
# 1  ваз 2107 оптом, Россия, Сочи, цены, предложени...
# 2  Цена, замена, тюнинг, купить, продать, ступица...
# 3
# 4
#
#                                                texts  \
# 0  Сняв рычаг с болтов, отводим его от поворотног...
# 1  при заказе от 5 шт. при заказе от 10 шт. при з...
# 2  |Ступица задняя левая ВАЗ ЛАДА Калина 2 С ABS|...
# 3  |Номенклатура ||21010 ||Цена | |00000094000000...
# 4  Ступица Нива — как провести ремонт и замену по...
#
#                                               titles  \
# 0      ВАЗ 21213 | Замена подшипников ступицы | Нива
# 1  Ваз 2107 оптом в Сочи. Сравнить цены, купить п...
# 2  Купить ступица Лада калина2. Трансмиссия - пер...
# 3                             Классика 21010 - 21074
# 4     Ступица Нива — замена подшипника своими руками
#
#                                           norm_title  \
# 0        ваз 21213 | замена подшипник ступица | нива
# 1  ваз 2107 оптом в сочи. сравнить цены, купить п...
# 2  купить ступица лада калина2. трансмиссия - пер...
# 3                             классика 21010 - 21074
# 4          ступица нива — замена подшипник свой рука
#
#                                        norm_keywords  \
# 0  замена подшипник ступицы, технический описание...
# 1  ваз 2107 оптом, россия, сочи, цены, предложени...
# 2  цена, замена, тюнинг, купить, продать, ступица...
# 3
# 4
#
#                                     norm_description  \
# 0  замена подшипник ступицы, руководство по ремон...
# 1  ваз 2107 оптом. продажа, поиск, поставщик и ма...
# 2  продажа запчасть ступица для легковой и грузов...
# 3
# 4  передний ступица нива иметь свой особенность в...
#
#                                            sum_title
# 0  ваз 21213 | замена подшипник ступица | нивазам...
# 1  ваз 2107 оптом в сочи. сравнить цены, купить п...
# 2  купить ступица лада калина2. трансмиссия - пер...
# 3                             классика 21010 - 21074
# 4  ступица нива — замена подшипник свой рукаперед...

# %% [markdown]
# # Идея 2.

# %% [markdown]
# Теперь нужно на основе нормализованных слов создать фичи. Используем различные способы обработки слов в группах.

# %%
def top_n_words(corpus, n=10):
    vectorizer = CountVectorizer(stop_words=stopwords.words('russian')).fit(corpus)
    bag_of_words = vectorizer.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    freq = sorted(freq, key = lambda x: x[1], reverse=True)
    return freq[:n]

# %%
def one_hot_groups(data):
    groups = np.arange(0, 310).reshape(-1, 1)
    onehot = OneHotEncoder()
    onehot.fit(groups)
    return onehot.transform(data.group_id.values.reshape(-1, 1))

# %% [markdown]
# Попытка раз: векторизуем с помощью TfidfVectorizer и берем полученные фичи.

# %%
def get_features(data):
    scaler = StandardScaler(with_mean=False)
    vectorizer = TfidfVectorizer(preprocessor=normalize_words, stop_words=stopwords.words('russian'), max_features=100)
    init = True
    for group in tqdm(data.group_id.unique()):
        corpus_ids = data.group_id == group
        
        # векторизуем все нормализованные столбцы, сначала фит по заголовкам
        vectorizer.fit(data.norm_title[corpus_ids])
        # затем уже векторизация и скейлинг
        vec_titles = vectorizer.transform(data.norm_title[corpus_ids])
        vec_titles = scaler.fit_transform(vec_titles)
        
        vec_texts = vectorizer.transform(data.texts[corpus_ids])
        vec_texts = scaler.fit_transform(vec_texts)
        
        vec_keywords = vectorizer.transform(data.norm_keywords[corpus_ids])
        vec_keywords = scaler.fit_transform(vec_keywords)
        
        vec_description = vectorizer.transform(data.norm_description[corpus_ids])
        vec_description = scaler.fit_transform(vec_description)
        
        vec_sumtitles = vectorizer.transform(data.sum_title[corpus_ids])
        vec_sumtitles = scaler.fit_transform(vec_sumtitles)
        
        # посчитаем косинусные расстояния между полученными векторами
        distmatr1 = pairwise_distances(vec_titles, vec_titles, metric='cosine')
        distmatr2 = pairwise_distances(vec_texts, vec_texts, metric='cosine')
        distmatr3 = pairwise_distances(vec_keywords, vec_keywords, metric='cosine')
        distmatr4 = pairwise_distances(vec_description, vec_description, metric='cosine')
        distmatr5 = pairwise_distances(vec_sumtitles, vec_sumtitles, metric='cosine')
        distmatr6 = pairwise_distances(vec_titles, vec_texts, metric='cosine')
        distmatr7 = pairwise_distances(vec_texts, vec_keywords, metric='cosine')
        distmatr8 = pairwise_distances(vec_keywords, vec_description, metric='cosine')
        distmatr9 = pairwise_distances(vec_description, vec_titles, metric='cosine')
        
        # возьмем средние
        meandist1 = distmatr1.mean(axis=1)
        meandist2 = distmatr2.mean(axis=1)
        meandist3 = distmatr3.mean(axis=1)
        meandist4 = distmatr4.mean(axis=1)
        meandist5 = distmatr5.mean(axis=1)
        meandist6 = distmatr6.mean(axis=1)
        meandist7 = distmatr7.mean(axis=1)
        meandist8 = distmatr8.mean(axis=1)
        meandist9 = distmatr9.mean(axis=1)
        
        # отсортируем
        distmatr1 = np.sort(distmatr1, axis=1)[:, 0:21]
        distmatr2 = np.sort(distmatr2, axis=1)[:, 0:21]
        distmatr3 = np.sort(distmatr3, axis=1)[:, 0:21]
        distmatr4 = np.sort(distmatr4, axis=1)[:, 0:21]
        distmatr5 = np.sort(distmatr5, axis=1)[:, 0:21]
        distmatr6 = np.sort(distmatr6, axis=1)[:, 0:21]
        distmatr7 = np.sort(distmatr7, axis=1)[:, 0:21]
        distmatr8 = np.sort(distmatr8, axis=1)[:, 0:21]
        distmatr9 = np.sort(distmatr9, axis=1)[:, 0:21]
        
        # и получим фичи
        distmatr1 = np.hstack((distmatr1, meandist1.reshape(-1, 1)))
        distmatr1 = np.hstack((distmatr1, meandist2.reshape(-1, 1)))
        distmatr1 = np.hstack((distmatr1, meandist3.reshape(-1, 1)))
        distmatr1 = np.hstack((distmatr1, meandist4.reshape(-1, 1)))
        distmatr1 = np.hstack((distmatr1, meandist5.reshape(-1, 1)))
        distmatr1 = np.hstack((distmatr1, meandist6.reshape(-1, 1)))
        distmatr1 = np.hstack((distmatr1, meandist7.reshape(-1, 1)))
        distmatr1 = np.hstack((distmatr1, meandist8.reshape(-1, 1)))
        distmatr1 = np.hstack((distmatr1, meandist9.reshape(-1, 1)))
        
        distmatr = np.hstack((distmatr1, distmatr2))
        distmatr = np.hstack((distmatr, distmatr3))
        distmatr = np.hstack((distmatr, distmatr4))
        distmatr = np.hstack((distmatr, distmatr5))
        distmatr = np.hstack((distmatr, distmatr6))
        distmatr = np.hstack((distmatr, distmatr7))
        distmatr = np.hstack((distmatr, distmatr8))
        distmatr = np.hstack((distmatr, distmatr9))

        if init:
            features = distmatr
        else:
            features = vstack((features, distmatr))
        init = False
    return features.tocsr()

# %%
onehotfeat = one_hot_groups(train_data)
features = get_features(train_data)
features = hstack([features, one_hot_groups(train_data)])
features = features.tocsr()
target = train_data.target.values
# Out:
#   0%|          | 0/129 [00:00<?, ?it/s]

# %%
features.shape
# Out:
# (11690, 508)

# %%
save_obj(features, 'features_test')

# %% [markdown]
# Посмотрим несколько разных моделей, валидируем и выберем наилучшую.

# %%
def get_score(X, y, model, n=3):
    groupkfold = GroupKFold(n_splits=n)
    scores = []
    for train_idx, test_idx in groupkfold.split(X, y, train_data.group_id):
        X_train, X_test, y_train, y_test = X[train_idx], X[test_idx], y[train_idx], y[test_idx]
        
        model.fit(X_train, y_train)
        pred = model.predict(X_test)
        score = f1_score(pred, y_test)
        scores.append(score)
    return np.mean(scores)

# %%
models = [
    xgboost.XGBClassifier(),
    RandomForestClassifier(),
    CatBoostClassifier(),
    lightgbm.LGBMClassifier(),
    GradientBoostingClassifier()
]
fin_scores = []
for model in models:
    fin_scores.append(get_score(features, target, model))
# Out:
# [19:08:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:08:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:08:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.024758
# 0:	learn: 0.6724548	total: 222ms	remaining: 3m 41s
# 1:	learn: 0.6550013	total: 248ms	remaining: 2m 3s
# 2:	learn: 0.6372687	total: 273ms	remaining: 1m 30s
# 3:	learn: 0.6220036	total: 303ms	remaining: 1m 15s
# 4:	learn: 0.6074692	total: 333ms	remaining: 1m 6s
# 5:	learn: 0.5930925	total: 361ms	remaining: 59.8s
# 6:	learn: 0.5799534	total: 388ms	remaining: 55s
# 7:	learn: 0.5659428	total: 414ms	remaining: 51.4s
# 8:	learn: 0.5533097	total: 442ms	remaining: 48.6s
# 9:	learn: 0.5425627	total: 468ms	remaining: 46.4s
# 10:	learn: 0.5326271	total: 496ms	remaining: 44.6s
# 11:	learn: 0.5222566	total: 526ms	remaining: 43.3s
# 12:	learn: 0.5134102	total: 555ms	remaining: 42.1s
# 13:	learn: 0.5046721	total: 582ms	remaining: 41s
# 14:	learn: 0.4964965	total: 608ms	remaining: 40s
# 15:	learn: 0.4892396	total: 637ms	remaining: 39.2s
# 16:	learn: 0.4817222	total: 666ms	remaining: 38.5s
# 17:	learn: 0.4741627	total: 691ms	remaining: 37.7s
# 18:	learn: 0.4681816	total: 725ms	remaining: 37.4s
# 19:	learn: 0.4623380	total: 757ms	remaining: 37.1s
# 20:	learn: 0.4569223	total: 786ms	remaining: 36.7s
# 21:	learn: 0.4519752	total: 814ms	remaining: 36.2s
# 22:	learn: 0.4471091	total: 841ms	remaining: 35.7s
# 23:	learn: 0.4418140	total: 868ms	remaining: 35.3s
# 24:	learn: 0.4372221	total: 892ms	remaining: 34.8s
# 25:	learn: 0.4326565	total: 917ms	remaining: 34.4s
# 26:	learn: 0.4278442	total: 944ms	remaining: 34s
# 27:	learn: 0.4231235	total: 969ms	remaining: 33.6s
# 28:	learn: 0.4192531	total: 995ms	remaining: 33.3s
# 29:	learn: 0.4161927	total: 1.02s	remaining: 33.1s
# 30:	learn: 0.4131345	total: 1.05s	remaining: 32.8s
# 31:	learn: 0.4103331	total: 1.07s	remaining: 32.5s
# 32:	learn: 0.4073767	total: 1.1s	remaining: 32.3s
# 33:	learn: 0.4044425	total: 1.13s	remaining: 32s
# 34:	learn: 0.4020447	total: 1.15s	remaining: 31.8s
# 35:	learn: 0.3995586	total: 1.18s	remaining: 31.6s
# 36:	learn: 0.3971157	total: 1.21s	remaining: 31.4s
# 37:	learn: 0.3950255	total: 1.24s	remaining: 31.3s
# 38:	learn: 0.3920755	total: 1.28s	remaining: 31.5s
# 39:	learn: 0.3899149	total: 1.31s	remaining: 31.6s
# 40:	learn: 0.3872845	total: 1.34s	remaining: 31.4s
# 41:	learn: 0.3855184	total: 1.37s	remaining: 31.2s
# 42:	learn: 0.3834127	total: 1.4s	remaining: 31.2s
# 43:	learn: 0.3812299	total: 1.44s	remaining: 31.3s
# 44:	learn: 0.3791601	total: 1.47s	remaining: 31.2s
# 45:	learn: 0.3775963	total: 1.5s	remaining: 31.2s
# 46:	learn: 0.3760059	total: 1.53s	remaining: 31.1s
# 47:	learn: 0.3742897	total: 1.56s	remaining: 31s
# 48:	learn: 0.3724402	total: 1.59s	remaining: 30.9s
# 49:	learn: 0.3707603	total: 1.62s	remaining: 30.7s
# 50:	learn: 0.3691917	total: 1.65s	remaining: 30.6s
# 51:	learn: 0.3676388	total: 1.67s	remaining: 30.5s
# 52:	learn: 0.3662249	total: 1.7s	remaining: 30.4s
# 53:	learn: 0.3646627	total: 1.73s	remaining: 30.3s
# 54:	learn: 0.3627868	total: 1.75s	remaining: 30.1s
# 55:	learn: 0.3614367	total: 1.78s	remaining: 30s
# 56:	learn: 0.3599448	total: 1.81s	remaining: 29.9s
# 57:	learn: 0.3588816	total: 1.84s	remaining: 29.8s
# 58:	learn: 0.3577530	total: 1.86s	remaining: 29.7s
# 59:	learn: 0.3567783	total: 1.89s	remaining: 29.6s
# 60:	learn: 0.3555696	total: 1.91s	remaining: 29.5s
# 61:	learn: 0.3546074	total: 1.94s	remaining: 29.3s
# 62:	learn: 0.3531311	total: 1.97s	remaining: 29.2s
# 63:	learn: 0.3523285	total: 1.99s	remaining: 29.1s
# 64:	learn: 0.3514343	total: 2.02s	remaining: 29s
# 65:	learn: 0.3501943	total: 2.05s	remaining: 29s
# 66:	learn: 0.3488811	total: 2.07s	remaining: 28.9s
# 67:	learn: 0.3480244	total: 2.1s	remaining: 28.8s
# 68:	learn: 0.3474063	total: 2.14s	remaining: 28.8s
# 69:	learn: 0.3463553	total: 2.17s	remaining: 28.8s
# 70:	learn: 0.3454844	total: 2.19s	remaining: 28.7s
# 71:	learn: 0.3446186	total: 2.22s	remaining: 28.6s
# 72:	learn: 0.3439121	total: 2.25s	remaining: 28.6s
# 73:	learn: 0.3431279	total: 2.3s	remaining: 28.8s
# 74:	learn: 0.3421284	total: 2.33s	remaining: 28.7s
# 75:	learn: 0.3412690	total: 2.36s	remaining: 28.7s
# 76:	learn: 0.3402285	total: 2.39s	remaining: 28.7s
# 77:	learn: 0.3390439	total: 2.43s	remaining: 28.7s
# 78:	learn: 0.3379451	total: 2.45s	remaining: 28.6s
# 79:	learn: 0.3372108	total: 2.48s	remaining: 28.6s
# 80:	learn: 0.3361952	total: 2.51s	remaining: 28.5s
# 81:	learn: 0.3357446	total: 2.54s	remaining: 28.4s
# 82:	learn: 0.3351802	total: 2.57s	remaining: 28.4s
# 83:	learn: 0.3345347	total: 2.59s	remaining: 28.3s
# 84:	learn: 0.3340681	total: 2.62s	remaining: 28.2s
# 85:	learn: 0.3332318	total: 2.65s	remaining: 28.1s
# 86:	learn: 0.3325383	total: 2.67s	remaining: 28s
# 87:	learn: 0.3319614	total: 2.69s	remaining: 27.9s
# 88:	learn: 0.3313716	total: 2.72s	remaining: 27.9s
# 89:	learn: 0.3307511	total: 2.75s	remaining: 27.8s
# 90:	learn: 0.3299027	total: 2.78s	remaining: 27.8s
# 91:	learn: 0.3289945	total: 2.81s	remaining: 27.7s
# 92:	learn: 0.3282969	total: 2.84s	remaining: 27.7s
# 93:	learn: 0.3276819	total: 2.87s	remaining: 27.7s
# 94:	learn: 0.3270684	total: 2.89s	remaining: 27.6s
# 95:	learn: 0.3262584	total: 2.92s	remaining: 27.5s
# 96:	learn: 0.3254610	total: 2.95s	remaining: 27.4s
# 97:	learn: 0.3250569	total: 2.97s	remaining: 27.4s
# 98:	learn: 0.3245237	total: 3s	remaining: 27.3s
# 99:	learn: 0.3240505	total: 3.03s	remaining: 27.2s
# 100:	learn: 0.3232264	total: 3.05s	remaining: 27.2s
# 101:	learn: 0.3228123	total: 3.08s	remaining: 27.1s
# 102:	learn: 0.3221791	total: 3.11s	remaining: 27.1s
# 103:	learn: 0.3217049	total: 3.14s	remaining: 27.1s
# 104:	learn: 0.3209674	total: 3.17s	remaining: 27s
# 105:	learn: 0.3204045	total: 3.2s	remaining: 27s
# 106:	learn: 0.3199795	total: 3.23s	remaining: 26.9s
# 107:	learn: 0.3195899	total: 3.25s	remaining: 26.9s
# 108:	learn: 0.3191037	total: 3.28s	remaining: 26.8s
# 109:	learn: 0.3186321	total: 3.31s	remaining: 26.8s
# 110:	learn: 0.3181821	total: 3.34s	remaining: 26.7s
# 111:	learn: 0.3175125	total: 3.37s	remaining: 26.7s
# 112:	learn: 0.3170584	total: 3.39s	remaining: 26.6s
# 113:	learn: 0.3165390	total: 3.42s	remaining: 26.6s
# 114:	learn: 0.3159183	total: 3.45s	remaining: 26.5s
# 115:	learn: 0.3154519	total: 3.48s	remaining: 26.5s
# 116:	learn: 0.3149415	total: 3.5s	remaining: 26.4s
# 117:	learn: 0.3145547	total: 3.53s	remaining: 26.4s
# 118:	learn: 0.3138680	total: 3.56s	remaining: 26.3s
# 119:	learn: 0.3134697	total: 3.58s	remaining: 26.3s
# 120:	learn: 0.3130775	total: 3.61s	remaining: 26.3s
# 121:	learn: 0.3127519	total: 3.64s	remaining: 26.2s
# 122:	learn: 0.3124209	total: 3.67s	remaining: 26.1s
# 123:	learn: 0.3120179	total: 3.69s	remaining: 26.1s
# 124:	learn: 0.3115972	total: 3.72s	remaining: 26s
# 125:	learn: 0.3111389	total: 3.74s	remaining: 26s
# 126:	learn: 0.3108456	total: 3.77s	remaining: 25.9s
# 127:	learn: 0.3103582	total: 3.79s	remaining: 25.9s
# 128:	learn: 0.3098841	total: 3.82s	remaining: 25.8s
# 129:	learn: 0.3095335	total: 3.85s	remaining: 25.8s
# 130:	learn: 0.3090729	total: 3.88s	remaining: 25.7s
# 131:	learn: 0.3087359	total: 3.9s	remaining: 25.7s
# 132:	learn: 0.3084622	total: 3.93s	remaining: 25.6s
# 133:	learn: 0.3081337	total: 3.96s	remaining: 25.6s
# 134:	learn: 0.3076365	total: 3.99s	remaining: 25.5s
# 135:	learn: 0.3073304	total: 4.01s	remaining: 25.5s
# 136:	learn: 0.3070471	total: 4.04s	remaining: 25.4s
# 137:	learn: 0.3067542	total: 4.07s	remaining: 25.4s
# 138:	learn: 0.3061962	total: 4.09s	remaining: 25.4s
# 139:	learn: 0.3059023	total: 4.12s	remaining: 25.3s
# 140:	learn: 0.3055965	total: 4.15s	remaining: 25.3s
# 141:	learn: 0.3052673	total: 4.17s	remaining: 25.2s
# 142:	learn: 0.3049843	total: 4.2s	remaining: 25.2s
# 143:	learn: 0.3047091	total: 4.23s	remaining: 25.1s
# 144:	learn: 0.3043499	total: 4.25s	remaining: 25.1s
# 145:	learn: 0.3039805	total: 4.28s	remaining: 25.1s
# 146:	learn: 0.3036872	total: 4.32s	remaining: 25s
# 147:	learn: 0.3033460	total: 4.35s	remaining: 25s
# 148:	learn: 0.3028872	total: 4.38s	remaining: 25s
# 149:	learn: 0.3025579	total: 4.41s	remaining: 25s
# 150:	learn: 0.3021986	total: 4.44s	remaining: 25s
# 151:	learn: 0.3019325	total: 4.47s	remaining: 25s
# 152:	learn: 0.3015117	total: 4.5s	remaining: 24.9s
# 153:	learn: 0.3011721	total: 4.54s	remaining: 24.9s
# 154:	learn: 0.3008142	total: 4.57s	remaining: 24.9s
# 155:	learn: 0.3005142	total: 4.59s	remaining: 24.9s
# 156:	learn: 0.3001293	total: 4.63s	remaining: 24.8s
# 157:	learn: 0.2999221	total: 4.65s	remaining: 24.8s
# 158:	learn: 0.2996691	total: 4.68s	remaining: 24.8s
# 159:	learn: 0.2993055	total: 4.71s	remaining: 24.7s
# 160:	learn: 0.2989788	total: 4.74s	remaining: 24.7s
# 161:	learn: 0.2987731	total: 4.77s	remaining: 24.7s
# 162:	learn: 0.2984737	total: 4.8s	remaining: 24.6s
# 163:	learn: 0.2981338	total: 4.83s	remaining: 24.6s
# 164:	learn: 0.2978819	total: 4.86s	remaining: 24.6s
# 165:	learn: 0.2974249	total: 4.89s	remaining: 24.6s
# 166:	learn: 0.2970627	total: 4.92s	remaining: 24.6s
# 167:	learn: 0.2966864	total: 4.95s	remaining: 24.5s
# 168:	learn: 0.2964047	total: 4.98s	remaining: 24.5s
# 169:	learn: 0.2961639	total: 5.01s	remaining: 24.5s
# 170:	learn: 0.2958775	total: 5.04s	remaining: 24.4s
# 171:	learn: 0.2955922	total: 5.07s	remaining: 24.4s
# 172:	learn: 0.2953111	total: 5.11s	remaining: 24.4s
# 173:	learn: 0.2950472	total: 5.13s	remaining: 24.4s
# 174:	learn: 0.2946570	total: 5.16s	remaining: 24.3s
# 175:	learn: 0.2943622	total: 5.2s	remaining: 24.3s
# 176:	learn: 0.2940194	total: 5.24s	remaining: 24.3s
# 177:	learn: 0.2937347	total: 5.27s	remaining: 24.3s
# 178:	learn: 0.2934367	total: 5.3s	remaining: 24.3s
# 179:	learn: 0.2930291	total: 5.33s	remaining: 24.3s
# 180:	learn: 0.2927771	total: 5.36s	remaining: 24.3s
# 181:	learn: 0.2924459	total: 5.39s	remaining: 24.2s
# 182:	learn: 0.2922152	total: 5.42s	remaining: 24.2s
# 183:	learn: 0.2919350	total: 5.46s	remaining: 24.2s
# 184:	learn: 0.2917216	total: 5.49s	remaining: 24.2s
# 185:	learn: 0.2912983	total: 5.51s	remaining: 24.1s
# 186:	learn: 0.2909905	total: 5.54s	remaining: 24.1s
# 187:	learn: 0.2907290	total: 5.58s	remaining: 24.1s
# 188:	learn: 0.2904465	total: 5.61s	remaining: 24.1s
# 189:	learn: 0.2901558	total: 5.64s	remaining: 24s
# 190:	learn: 0.2899362	total: 5.67s	remaining: 24s
# 191:	learn: 0.2896269	total: 5.7s	remaining: 24s
# 192:	learn: 0.2893900	total: 5.73s	remaining: 24s
# 193:	learn: 0.2891130	total: 5.76s	remaining: 23.9s
# 194:	learn: 0.2888695	total: 5.79s	remaining: 23.9s
# 195:	learn: 0.2884632	total: 5.82s	remaining: 23.9s
# 196:	learn: 0.2882160	total: 5.84s	remaining: 23.8s
# 197:	learn: 0.2879843	total: 5.87s	remaining: 23.8s
# 198:	learn: 0.2877134	total: 5.9s	remaining: 23.8s
# 199:	learn: 0.2873895	total: 5.93s	remaining: 23.7s
# 200:	learn: 0.2871697	total: 5.96s	remaining: 23.7s
# 201:	learn: 0.2870794	total: 5.99s	remaining: 23.7s
# 202:	learn: 0.2867849	total: 6.02s	remaining: 23.6s
# 203:	learn: 0.2865375	total: 6.05s	remaining: 23.6s
# 204:	learn: 0.2863268	total: 6.09s	remaining: 23.6s
# 205:	learn: 0.2861213	total: 6.12s	remaining: 23.6s
# 206:	learn: 0.2856558	total: 6.15s	remaining: 23.6s
# 207:	learn: 0.2853843	total: 6.18s	remaining: 23.5s
# 208:	learn: 0.2851082	total: 6.22s	remaining: 23.5s
# 209:	learn: 0.2849293	total: 6.25s	remaining: 23.5s
# 210:	learn: 0.2847105	total: 6.28s	remaining: 23.5s
# 211:	learn: 0.2844216	total: 6.31s	remaining: 23.5s
# 212:	learn: 0.2841204	total: 6.34s	remaining: 23.4s
# 213:	learn: 0.2838861	total: 6.37s	remaining: 23.4s
# 214:	learn: 0.2836843	total: 6.4s	remaining: 23.4s
# 215:	learn: 0.2834173	total: 6.43s	remaining: 23.4s
# 216:	learn: 0.2831273	total: 6.46s	remaining: 23.3s
# 217:	learn: 0.2828554	total: 6.49s	remaining: 23.3s
# 218:	learn: 0.2825587	total: 6.52s	remaining: 23.3s
# 219:	learn: 0.2823023	total: 6.55s	remaining: 23.2s
# 220:	learn: 0.2820438	total: 6.59s	remaining: 23.2s
# 221:	learn: 0.2818610	total: 6.62s	remaining: 23.2s
# 222:	learn: 0.2816938	total: 6.64s	remaining: 23.2s
# 223:	learn: 0.2814131	total: 6.67s	remaining: 23.1s
# 224:	learn: 0.2811110	total: 6.7s	remaining: 23.1s
# 225:	learn: 0.2808745	total: 6.73s	remaining: 23.1s
# 226:	learn: 0.2805792	total: 6.76s	remaining: 23s
# 227:	learn: 0.2803662	total: 6.79s	remaining: 23s
# 228:	learn: 0.2801539	total: 6.82s	remaining: 23s
# 229:	learn: 0.2799449	total: 6.85s	remaining: 22.9s
# 230:	learn: 0.2796875	total: 6.88s	remaining: 22.9s
# 231:	learn: 0.2793810	total: 6.91s	remaining: 22.9s
# 232:	learn: 0.2790573	total: 6.94s	remaining: 22.8s
# 233:	learn: 0.2787944	total: 6.97s	remaining: 22.8s
# 234:	learn: 0.2785396	total: 7s	remaining: 22.8s
# 235:	learn: 0.2782784	total: 7.03s	remaining: 22.8s
# 236:	learn: 0.2780391	total: 7.06s	remaining: 22.7s
# 237:	learn: 0.2777994	total: 7.09s	remaining: 22.7s
# 238:	learn: 0.2776509	total: 7.12s	remaining: 22.7s
# 239:	learn: 0.2774493	total: 7.15s	remaining: 22.6s
# 240:	learn: 0.2773059	total: 7.18s	remaining: 22.6s
# 241:	learn: 0.2771353	total: 7.22s	remaining: 22.6s
# 242:	learn: 0.2768715	total: 7.25s	remaining: 22.6s
# 243:	learn: 0.2765988	total: 7.28s	remaining: 22.6s
# 244:	learn: 0.2763279	total: 7.31s	remaining: 22.5s
# 245:	learn: 0.2760135	total: 7.34s	remaining: 22.5s
# 246:	learn: 0.2757259	total: 7.38s	remaining: 22.5s
# 247:	learn: 0.2755421	total: 7.41s	remaining: 22.5s
# 248:	learn: 0.2752413	total: 7.44s	remaining: 22.4s
# 249:	learn: 0.2750988	total: 7.47s	remaining: 22.4s
# 250:	learn: 0.2748041	total: 7.51s	remaining: 22.4s
# 251:	learn: 0.2744989	total: 7.54s	remaining: 22.4s
# 252:	learn: 0.2742145	total: 7.56s	remaining: 22.3s
# 253:	learn: 0.2740517	total: 7.59s	remaining: 22.3s
# 254:	learn: 0.2738176	total: 7.62s	remaining: 22.3s
# 255:	learn: 0.2735766	total: 7.65s	remaining: 22.2s
# 256:	learn: 0.2732714	total: 7.67s	remaining: 22.2s
# 257:	learn: 0.2729044	total: 7.71s	remaining: 22.2s
# 258:	learn: 0.2727166	total: 7.74s	remaining: 22.1s
# 259:	learn: 0.2724172	total: 7.76s	remaining: 22.1s
# 260:	learn: 0.2721464	total: 7.79s	remaining: 22.1s
# 261:	learn: 0.2718971	total: 7.82s	remaining: 22s
# 262:	learn: 0.2715832	total: 7.86s	remaining: 22s
# 263:	learn: 0.2713849	total: 7.89s	remaining: 22s
# 264:	learn: 0.2711992	total: 7.93s	remaining: 22s
# 265:	learn: 0.2710075	total: 7.96s	remaining: 22s
# 266:	learn: 0.2707030	total: 7.99s	remaining: 21.9s
# 267:	learn: 0.2704407	total: 8.03s	remaining: 21.9s
# 268:	learn: 0.2702951	total: 8.05s	remaining: 21.9s
# 269:	learn: 0.2700930	total: 8.09s	remaining: 21.9s
# 270:	learn: 0.2697949	total: 8.11s	remaining: 21.8s
# 271:	learn: 0.2696155	total: 8.16s	remaining: 21.8s
# 272:	learn: 0.2694429	total: 8.19s	remaining: 21.8s
# 273:	learn: 0.2692188	total: 8.22s	remaining: 21.8s
# 274:	learn: 0.2689588	total: 8.25s	remaining: 21.8s
# 275:	learn: 0.2687944	total: 8.28s	remaining: 21.7s
# 276:	learn: 0.2685273	total: 8.31s	remaining: 21.7s
# 277:	learn: 0.2683128	total: 8.34s	remaining: 21.7s
# 278:	learn: 0.2680396	total: 8.37s	remaining: 21.6s
# 279:	learn: 0.2678379	total: 8.4s	remaining: 21.6s
# 280:	learn: 0.2676523	total: 8.44s	remaining: 21.6s
# 281:	learn: 0.2674335	total: 8.46s	remaining: 21.6s
# 282:	learn: 0.2672603	total: 8.49s	remaining: 21.5s
# 283:	learn: 0.2669980	total: 8.53s	remaining: 21.5s
# 284:	learn: 0.2667599	total: 8.56s	remaining: 21.5s
# 285:	learn: 0.2665844	total: 8.6s	remaining: 21.5s
# 286:	learn: 0.2663911	total: 8.63s	remaining: 21.5s
# 287:	learn: 0.2662131	total: 8.67s	remaining: 21.4s
# 288:	learn: 0.2659566	total: 8.7s	remaining: 21.4s
# 289:	learn: 0.2657546	total: 8.73s	remaining: 21.4s
# 290:	learn: 0.2655428	total: 8.76s	remaining: 21.3s
# 291:	learn: 0.2654597	total: 8.79s	remaining: 21.3s
# 292:	learn: 0.2653264	total: 8.81s	remaining: 21.3s
# 293:	learn: 0.2650903	total: 8.84s	remaining: 21.2s
# 294:	learn: 0.2648785	total: 8.88s	remaining: 21.2s
# 295:	learn: 0.2646587	total: 8.91s	remaining: 21.2s
# 296:	learn: 0.2644451	total: 8.95s	remaining: 21.2s
# 297:	learn: 0.2642811	total: 8.98s	remaining: 21.1s
# 298:	learn: 0.2641018	total: 9.01s	remaining: 21.1s
# 299:	learn: 0.2639273	total: 9.04s	remaining: 21.1s
# 300:	learn: 0.2637223	total: 9.07s	remaining: 21.1s
# 301:	learn: 0.2634957	total: 9.1s	remaining: 21s
# 302:	learn: 0.2632877	total: 9.13s	remaining: 21s
# 303:	learn: 0.2630412	total: 9.16s	remaining: 21s
# 304:	learn: 0.2627655	total: 9.19s	remaining: 20.9s
# 305:	learn: 0.2625549	total: 9.22s	remaining: 20.9s
# 306:	learn: 0.2623302	total: 9.25s	remaining: 20.9s
# 307:	learn: 0.2621035	total: 9.28s	remaining: 20.8s
# 308:	learn: 0.2618201	total: 9.31s	remaining: 20.8s
# 309:	learn: 0.2615818	total: 9.34s	remaining: 20.8s
# 310:	learn: 0.2613537	total: 9.37s	remaining: 20.7s
# 311:	learn: 0.2612195	total: 9.39s	remaining: 20.7s
# 312:	learn: 0.2609716	total: 9.43s	remaining: 20.7s
# 313:	learn: 0.2607419	total: 9.46s	remaining: 20.7s
# 314:	learn: 0.2604163	total: 9.49s	remaining: 20.6s
# 315:	learn: 0.2603107	total: 9.52s	remaining: 20.6s
# 316:	learn: 0.2601518	total: 9.54s	remaining: 20.6s
# 317:	learn: 0.2599241	total: 9.57s	remaining: 20.5s
# 318:	learn: 0.2597300	total: 9.6s	remaining: 20.5s
# 319:	learn: 0.2596035	total: 9.63s	remaining: 20.5s
# 320:	learn: 0.2593939	total: 9.67s	remaining: 20.5s
# 321:	learn: 0.2591299	total: 9.71s	remaining: 20.4s
# 322:	learn: 0.2588609	total: 9.75s	remaining: 20.4s
# 323:	learn: 0.2586734	total: 9.79s	remaining: 20.4s
# 324:	learn: 0.2584521	total: 9.82s	remaining: 20.4s
# 325:	learn: 0.2582123	total: 9.85s	remaining: 20.4s
# 326:	learn: 0.2578993	total: 9.88s	remaining: 20.3s
# 327:	learn: 0.2576092	total: 9.91s	remaining: 20.3s
# 328:	learn: 0.2573682	total: 9.95s	remaining: 20.3s
# 329:	learn: 0.2571667	total: 9.98s	remaining: 20.3s
# 330:	learn: 0.2569787	total: 10s	remaining: 20.3s
# 331:	learn: 0.2567696	total: 10.1s	remaining: 20.3s
# 332:	learn: 0.2565781	total: 10.1s	remaining: 20.2s
# 333:	learn: 0.2563496	total: 10.1s	remaining: 20.2s
# 334:	learn: 0.2561726	total: 10.2s	remaining: 20.2s
# 335:	learn: 0.2559890	total: 10.2s	remaining: 20.2s
# 336:	learn: 0.2557560	total: 10.2s	remaining: 20.1s
# 337:	learn: 0.2555802	total: 10.3s	remaining: 20.1s
# 338:	learn: 0.2553601	total: 10.3s	remaining: 20.1s
# 339:	learn: 0.2551861	total: 10.3s	remaining: 20s
# 340:	learn: 0.2549184	total: 10.4s	remaining: 20s
# 341:	learn: 0.2547330	total: 10.4s	remaining: 20s
# 342:	learn: 0.2545536	total: 10.4s	remaining: 19.9s
# 343:	learn: 0.2542809	total: 10.4s	remaining: 19.9s
# 344:	learn: 0.2540503	total: 10.5s	remaining: 19.9s
# 345:	learn: 0.2538129	total: 10.5s	remaining: 19.9s
# 346:	learn: 0.2536019	total: 10.5s	remaining: 19.8s
# 347:	learn: 0.2533405	total: 10.6s	remaining: 19.8s
# 348:	learn: 0.2531517	total: 10.6s	remaining: 19.8s
# 349:	learn: 0.2529597	total: 10.6s	remaining: 19.7s
# 350:	learn: 0.2528086	total: 10.6s	remaining: 19.7s
# 351:	learn: 0.2526065	total: 10.7s	remaining: 19.7s
# 352:	learn: 0.2524060	total: 10.7s	remaining: 19.6s
# 353:	learn: 0.2521785	total: 10.7s	remaining: 19.6s
# 354:	learn: 0.2519357	total: 10.8s	remaining: 19.6s
# 355:	learn: 0.2516848	total: 10.8s	remaining: 19.5s
# 356:	learn: 0.2514594	total: 10.8s	remaining: 19.5s
# 357:	learn: 0.2512712	total: 10.9s	remaining: 19.5s
# 358:	learn: 0.2510658	total: 10.9s	remaining: 19.5s
# 359:	learn: 0.2508834	total: 10.9s	remaining: 19.4s
# 360:	learn: 0.2505719	total: 11s	remaining: 19.4s
# 361:	learn: 0.2504048	total: 11s	remaining: 19.4s
# 362:	learn: 0.2502520	total: 11s	remaining: 19.4s
# 363:	learn: 0.2500396	total: 11.1s	remaining: 19.3s
# 364:	learn: 0.2497869	total: 11.1s	remaining: 19.3s
# 365:	learn: 0.2495668	total: 11.1s	remaining: 19.3s
# 366:	learn: 0.2492870	total: 11.2s	remaining: 19.3s
# 367:	learn: 0.2490679	total: 11.2s	remaining: 19.2s
# 368:	learn: 0.2488685	total: 11.2s	remaining: 19.2s
# 369:	learn: 0.2485874	total: 11.3s	remaining: 19.2s
# 370:	learn: 0.2483667	total: 11.3s	remaining: 19.2s
# 371:	learn: 0.2482088	total: 11.3s	remaining: 19.1s
# 372:	learn: 0.2480410	total: 11.4s	remaining: 19.1s
# 373:	learn: 0.2477536	total: 11.4s	remaining: 19.1s
# 374:	learn: 0.2475093	total: 11.4s	remaining: 19s
# 375:	learn: 0.2472681	total: 11.4s	remaining: 19s
# 376:	learn: 0.2471113	total: 11.5s	remaining: 19s
# 377:	learn: 0.2469223	total: 11.5s	remaining: 18.9s
# 378:	learn: 0.2467335	total: 11.5s	remaining: 18.9s
# 379:	learn: 0.2464793	total: 11.6s	remaining: 18.9s
# 380:	learn: 0.2462139	total: 11.6s	remaining: 18.8s
# 381:	learn: 0.2460233	total: 11.6s	remaining: 18.8s
# 382:	learn: 0.2457546	total: 11.7s	remaining: 18.8s
# 383:	learn: 0.2455027	total: 11.7s	remaining: 18.8s
# 384:	learn: 0.2453083	total: 11.7s	remaining: 18.7s
# 385:	learn: 0.2450088	total: 11.8s	remaining: 18.7s
# 386:	learn: 0.2447528	total: 11.8s	remaining: 18.7s
# 387:	learn: 0.2445966	total: 11.8s	remaining: 18.6s
# 388:	learn: 0.2443675	total: 11.8s	remaining: 18.6s
# 389:	learn: 0.2440772	total: 11.9s	remaining: 18.6s
# 390:	learn: 0.2438638	total: 11.9s	remaining: 18.5s
# 391:	learn: 0.2436423	total: 11.9s	remaining: 18.5s
# 392:	learn: 0.2434227	total: 12s	remaining: 18.5s
# 393:	learn: 0.2432389	total: 12s	remaining: 18.4s
# 394:	learn: 0.2429785	total: 12s	remaining: 18.4s
# 395:	learn: 0.2427830	total: 12.1s	remaining: 18.4s
# 396:	learn: 0.2425202	total: 12.1s	remaining: 18.3s
# 397:	learn: 0.2422024	total: 12.1s	remaining: 18.3s
# 398:	learn: 0.2419886	total: 12.2s	remaining: 18.3s
# 399:	learn: 0.2417645	total: 12.2s	remaining: 18.3s
# 400:	learn: 0.2415546	total: 12.2s	remaining: 18.3s
# 401:	learn: 0.2412795	total: 12.3s	remaining: 18.2s
# 402:	learn: 0.2410269	total: 12.3s	remaining: 18.2s
# 403:	learn: 0.2407745	total: 12.3s	remaining: 18.2s
# 404:	learn: 0.2405038	total: 12.3s	remaining: 18.1s
# 405:	learn: 0.2402606	total: 12.4s	remaining: 18.1s
# 406:	learn: 0.2400149	total: 12.4s	remaining: 18.1s
# 407:	learn: 0.2398014	total: 12.4s	remaining: 18s
# 408:	learn: 0.2395710	total: 12.5s	remaining: 18s
# 409:	learn: 0.2393344	total: 12.5s	remaining: 18s
# 410:	learn: 0.2391297	total: 12.5s	remaining: 17.9s
# 411:	learn: 0.2388787	total: 12.6s	remaining: 17.9s
# 412:	learn: 0.2386769	total: 12.6s	remaining: 17.9s
# 413:	learn: 0.2384233	total: 12.6s	remaining: 17.9s
# 414:	learn: 0.2381676	total: 12.6s	remaining: 17.8s
# 415:	learn: 0.2379935	total: 12.7s	remaining: 17.8s
# 416:	learn: 0.2377491	total: 12.7s	remaining: 17.8s
# 417:	learn: 0.2375111	total: 12.7s	remaining: 17.7s
# 418:	learn: 0.2372884	total: 12.8s	remaining: 17.7s
# 419:	learn: 0.2370270	total: 12.8s	remaining: 17.7s
# 420:	learn: 0.2368134	total: 12.8s	remaining: 17.6s
# 421:	learn: 0.2365812	total: 12.8s	remaining: 17.6s
# 422:	learn: 0.2363565	total: 12.9s	remaining: 17.6s
# 423:	learn: 0.2361831	total: 12.9s	remaining: 17.5s
# 424:	learn: 0.2359697	total: 12.9s	remaining: 17.5s
# 425:	learn: 0.2358074	total: 13s	remaining: 17.5s
# 426:	learn: 0.2355765	total: 13s	remaining: 17.4s
# 427:	learn: 0.2353655	total: 13s	remaining: 17.4s
# 428:	learn: 0.2351174	total: 13.1s	remaining: 17.4s
# 429:	learn: 0.2348497	total: 13.1s	remaining: 17.4s
# 430:	learn: 0.2346016	total: 13.1s	remaining: 17.3s
# 431:	learn: 0.2343600	total: 13.2s	remaining: 17.3s
# 432:	learn: 0.2341369	total: 13.2s	remaining: 17.3s
# 433:	learn: 0.2338994	total: 13.2s	remaining: 17.3s
# 434:	learn: 0.2336867	total: 13.3s	remaining: 17.2s
# 435:	learn: 0.2334499	total: 13.3s	remaining: 17.2s
# 436:	learn: 0.2332573	total: 13.3s	remaining: 17.2s
# 437:	learn: 0.2330499	total: 13.4s	remaining: 17.1s
# 438:	learn: 0.2327601	total: 13.4s	remaining: 17.1s
# 439:	learn: 0.2325559	total: 13.4s	remaining: 17.1s
# 440:	learn: 0.2323143	total: 13.5s	remaining: 17.1s
# 441:	learn: 0.2320654	total: 13.5s	remaining: 17s
# 442:	learn: 0.2318731	total: 13.5s	remaining: 17s
# 443:	learn: 0.2316834	total: 13.5s	remaining: 17s
# 444:	learn: 0.2313976	total: 13.6s	remaining: 16.9s
# 445:	learn: 0.2311496	total: 13.6s	remaining: 16.9s
# 446:	learn: 0.2309245	total: 13.6s	remaining: 16.9s
# 447:	learn: 0.2306796	total: 13.7s	remaining: 16.8s
# 448:	learn: 0.2304405	total: 13.7s	remaining: 16.8s
# 449:	learn: 0.2302288	total: 13.7s	remaining: 16.8s
# 450:	learn: 0.2300032	total: 13.7s	remaining: 16.7s
# 451:	learn: 0.2297892	total: 13.8s	remaining: 16.7s
# 452:	learn: 0.2295807	total: 13.8s	remaining: 16.7s
# 453:	learn: 0.2293370	total: 13.8s	remaining: 16.6s
# 454:	learn: 0.2291015	total: 13.9s	remaining: 16.6s
# 455:	learn: 0.2288534	total: 13.9s	remaining: 16.6s
# 456:	learn: 0.2286331	total: 13.9s	remaining: 16.5s
# 457:	learn: 0.2284019	total: 13.9s	remaining: 16.5s
# 458:	learn: 0.2282285	total: 14s	remaining: 16.5s
# 459:	learn: 0.2280592	total: 14s	remaining: 16.4s
# 460:	learn: 0.2278800	total: 14.1s	remaining: 16.4s
# 461:	learn: 0.2275853	total: 14.1s	remaining: 16.4s
# 462:	learn: 0.2273889	total: 14.1s	remaining: 16.4s
# 463:	learn: 0.2272078	total: 14.2s	remaining: 16.4s
# 464:	learn: 0.2270023	total: 14.2s	remaining: 16.3s
# 465:	learn: 0.2267477	total: 14.2s	remaining: 16.3s
# 466:	learn: 0.2265500	total: 14.3s	remaining: 16.3s
# 467:	learn: 0.2263121	total: 14.3s	remaining: 16.2s
# 468:	learn: 0.2261155	total: 14.3s	remaining: 16.2s
# 469:	learn: 0.2258863	total: 14.3s	remaining: 16.2s
# 470:	learn: 0.2256620	total: 14.4s	remaining: 16.1s
# 471:	learn: 0.2254833	total: 14.4s	remaining: 16.1s
# 472:	learn: 0.2252912	total: 14.4s	remaining: 16.1s
# 473:	learn: 0.2250566	total: 14.5s	remaining: 16.1s
# 474:	learn: 0.2248898	total: 14.5s	remaining: 16s
# 475:	learn: 0.2246621	total: 14.5s	remaining: 16s
# 476:	learn: 0.2244287	total: 14.6s	remaining: 16s
# 477:	learn: 0.2242310	total: 14.6s	remaining: 16s
# 478:	learn: 0.2239833	total: 14.6s	remaining: 15.9s
# 479:	learn: 0.2237705	total: 14.7s	remaining: 15.9s
# 480:	learn: 0.2235352	total: 14.7s	remaining: 15.9s
# 481:	learn: 0.2233183	total: 14.7s	remaining: 15.8s
# 482:	learn: 0.2230957	total: 14.8s	remaining: 15.8s
# 483:	learn: 0.2228451	total: 14.8s	remaining: 15.8s
# 484:	learn: 0.2226635	total: 14.8s	remaining: 15.7s
# 485:	learn: 0.2224560	total: 14.9s	remaining: 15.7s
# 486:	learn: 0.2222500	total: 14.9s	remaining: 15.7s
# 487:	learn: 0.2220299	total: 14.9s	remaining: 15.6s
# 488:	learn: 0.2218652	total: 14.9s	remaining: 15.6s
# 489:	learn: 0.2216228	total: 15s	remaining: 15.6s
# 490:	learn: 0.2214405	total: 15s	remaining: 15.6s
# 491:	learn: 0.2212901	total: 15s	remaining: 15.5s
# 492:	learn: 0.2210795	total: 15.1s	remaining: 15.5s
# 493:	learn: 0.2208804	total: 15.1s	remaining: 15.5s
# 494:	learn: 0.2206518	total: 15.1s	remaining: 15.4s
# 495:	learn: 0.2204149	total: 15.2s	remaining: 15.4s
# 496:	learn: 0.2202168	total: 15.2s	remaining: 15.4s
# 497:	learn: 0.2200949	total: 15.2s	remaining: 15.3s
# 498:	learn: 0.2198806	total: 15.3s	remaining: 15.3s
# 499:	learn: 0.2196973	total: 15.3s	remaining: 15.3s
# 500:	learn: 0.2195071	total: 15.3s	remaining: 15.3s
# 501:	learn: 0.2193258	total: 15.3s	remaining: 15.2s
# 502:	learn: 0.2190767	total: 15.4s	remaining: 15.2s
# 503:	learn: 0.2189295	total: 15.4s	remaining: 15.2s
# 504:	learn: 0.2186814	total: 15.4s	remaining: 15.1s
# 505:	learn: 0.2185213	total: 15.5s	remaining: 15.1s
# 506:	learn: 0.2182865	total: 15.5s	remaining: 15.1s
# 507:	learn: 0.2181003	total: 15.5s	remaining: 15s
# 508:	learn: 0.2178823	total: 15.6s	remaining: 15s
# 509:	learn: 0.2176659	total: 15.6s	remaining: 15s
# 510:	learn: 0.2174635	total: 15.6s	remaining: 15s
# 511:	learn: 0.2172141	total: 15.7s	remaining: 14.9s
# 512:	learn: 0.2169461	total: 15.7s	remaining: 14.9s
# 513:	learn: 0.2167574	total: 15.7s	remaining: 14.9s
# 514:	learn: 0.2165464	total: 15.8s	remaining: 14.8s
# 515:	learn: 0.2163244	total: 15.8s	remaining: 14.8s
# 516:	learn: 0.2161077	total: 15.8s	remaining: 14.8s
# 517:	learn: 0.2159352	total: 15.8s	remaining: 14.7s
# 518:	learn: 0.2157345	total: 15.9s	remaining: 14.7s
# 519:	learn: 0.2155080	total: 15.9s	remaining: 14.7s
# 520:	learn: 0.2152752	total: 16s	remaining: 14.7s
# 521:	learn: 0.2150681	total: 16s	remaining: 14.7s
# 522:	learn: 0.2148831	total: 16s	remaining: 14.6s
# 523:	learn: 0.2146425	total: 16.1s	remaining: 14.6s
# 524:	learn: 0.2144353	total: 16.1s	remaining: 14.6s
# 525:	learn: 0.2142277	total: 16.2s	remaining: 14.6s
# 526:	learn: 0.2139842	total: 16.2s	remaining: 14.5s
# 527:	learn: 0.2138039	total: 16.2s	remaining: 14.5s
# 528:	learn: 0.2135787	total: 16.3s	remaining: 14.5s
# 529:	learn: 0.2134030	total: 16.3s	remaining: 14.5s
# 530:	learn: 0.2132372	total: 16.3s	remaining: 14.4s
# 531:	learn: 0.2129921	total: 16.4s	remaining: 14.4s
# 532:	learn: 0.2128103	total: 16.4s	remaining: 14.4s
# 533:	learn: 0.2126740	total: 16.4s	remaining: 14.3s
# 534:	learn: 0.2124872	total: 16.5s	remaining: 14.3s
# 535:	learn: 0.2122431	total: 16.5s	remaining: 14.3s
# 536:	learn: 0.2120340	total: 16.5s	remaining: 14.3s
# 537:	learn: 0.2118822	total: 16.6s	remaining: 14.2s
# 538:	learn: 0.2116406	total: 16.6s	remaining: 14.2s
# 539:	learn: 0.2114745	total: 16.6s	remaining: 14.2s
# 540:	learn: 0.2112866	total: 16.6s	remaining: 14.1s
# 541:	learn: 0.2110650	total: 16.7s	remaining: 14.1s
# 542:	learn: 0.2109189	total: 16.7s	remaining: 14.1s
# 543:	learn: 0.2106792	total: 16.7s	remaining: 14s
# 544:	learn: 0.2105156	total: 16.8s	remaining: 14s
# 545:	learn: 0.2103383	total: 16.8s	remaining: 14s
# 546:	learn: 0.2101345	total: 16.8s	remaining: 13.9s
# 547:	learn: 0.2099508	total: 16.9s	remaining: 13.9s
# 548:	learn: 0.2097832	total: 16.9s	remaining: 13.9s
# 549:	learn: 0.2096666	total: 16.9s	remaining: 13.8s
# 550:	learn: 0.2095056	total: 17s	remaining: 13.8s
# 551:	learn: 0.2092948	total: 17s	remaining: 13.8s
# 552:	learn: 0.2090764	total: 17s	remaining: 13.8s
# 553:	learn: 0.2088704	total: 17.1s	remaining: 13.7s
# 554:	learn: 0.2086673	total: 17.1s	remaining: 13.7s
# 555:	learn: 0.2085118	total: 17.1s	remaining: 13.7s
# 556:	learn: 0.2083549	total: 17.2s	remaining: 13.6s
# 557:	learn: 0.2081307	total: 17.2s	remaining: 13.6s
# 558:	learn: 0.2079629	total: 17.2s	remaining: 13.6s
# 559:	learn: 0.2077611	total: 17.3s	remaining: 13.6s
# 560:	learn: 0.2075478	total: 17.3s	remaining: 13.5s
# 561:	learn: 0.2074064	total: 17.3s	remaining: 13.5s
# 562:	learn: 0.2072417	total: 17.4s	remaining: 13.5s
# 563:	learn: 0.2070083	total: 17.4s	remaining: 13.4s
# 564:	learn: 0.2068362	total: 17.4s	remaining: 13.4s
# 565:	learn: 0.2066525	total: 17.4s	remaining: 13.4s
# 566:	learn: 0.2064531	total: 17.5s	remaining: 13.3s
# 567:	learn: 0.2062844	total: 17.5s	remaining: 13.3s
# 568:	learn: 0.2060579	total: 17.5s	remaining: 13.3s
# 569:	learn: 0.2059093	total: 17.6s	remaining: 13.2s
# 570:	learn: 0.2057638	total: 17.6s	remaining: 13.2s
# 571:	learn: 0.2055363	total: 17.6s	remaining: 13.2s
# 572:	learn: 0.2053084	total: 17.6s	remaining: 13.1s
# 573:	learn: 0.2051480	total: 17.7s	remaining: 13.1s
# 574:	learn: 0.2049536	total: 17.7s	remaining: 13.1s
# 575:	learn: 0.2048178	total: 17.7s	remaining: 13s
# 576:	learn: 0.2045839	total: 17.8s	remaining: 13s
# 577:	learn: 0.2044015	total: 17.8s	remaining: 13s
# 578:	learn: 0.2042172	total: 17.8s	remaining: 12.9s
# 579:	learn: 0.2040151	total: 17.8s	remaining: 12.9s
# 580:	learn: 0.2038754	total: 17.9s	remaining: 12.9s
# 581:	learn: 0.2037351	total: 17.9s	remaining: 12.9s
# 582:	learn: 0.2036106	total: 17.9s	remaining: 12.8s
# 583:	learn: 0.2034619	total: 18s	remaining: 12.8s
# 584:	learn: 0.2032968	total: 18s	remaining: 12.8s
# 585:	learn: 0.2030948	total: 18s	remaining: 12.7s
# 586:	learn: 0.2029121	total: 18.1s	remaining: 12.7s
# 587:	learn: 0.2026653	total: 18.1s	remaining: 12.7s
# 588:	learn: 0.2025598	total: 18.1s	remaining: 12.6s
# 589:	learn: 0.2023746	total: 18.2s	remaining: 12.6s
# 590:	learn: 0.2021532	total: 18.2s	remaining: 12.6s
# 591:	learn: 0.2020234	total: 18.2s	remaining: 12.6s
# 592:	learn: 0.2018649	total: 18.3s	remaining: 12.5s
# 593:	learn: 0.2016856	total: 18.3s	remaining: 12.5s
# 594:	learn: 0.2015359	total: 18.3s	remaining: 12.5s
# 595:	learn: 0.2013759	total: 18.4s	remaining: 12.4s
# 596:	learn: 0.2012245	total: 18.4s	remaining: 12.4s
# 597:	learn: 0.2010664	total: 18.4s	remaining: 12.4s
# 598:	learn: 0.2008543	total: 18.5s	remaining: 12.4s
# 599:	learn: 0.2007065	total: 18.5s	remaining: 12.3s
# 600:	learn: 0.2005131	total: 18.5s	remaining: 12.3s
# 601:	learn: 0.2003512	total: 18.5s	remaining: 12.3s
# 602:	learn: 0.2001782	total: 18.6s	remaining: 12.2s
# 603:	learn: 0.2000259	total: 18.6s	remaining: 12.2s
# 604:	learn: 0.1998581	total: 18.6s	remaining: 12.2s
# 605:	learn: 0.1996442	total: 18.7s	remaining: 12.1s
# 606:	learn: 0.1994981	total: 18.7s	remaining: 12.1s
# 607:	learn: 0.1992999	total: 18.7s	remaining: 12.1s
# 608:	learn: 0.1991642	total: 18.7s	remaining: 12s
# 609:	learn: 0.1989905	total: 18.8s	remaining: 12s
# 610:	learn: 0.1988958	total: 18.8s	remaining: 12s
# 611:	learn: 0.1987026	total: 18.8s	remaining: 11.9s
# 612:	learn: 0.1985486	total: 18.9s	remaining: 11.9s
# 613:	learn: 0.1983856	total: 18.9s	remaining: 11.9s
# 614:	learn: 0.1981584	total: 18.9s	remaining: 11.9s
# 615:	learn: 0.1979968	total: 19s	remaining: 11.8s
# 616:	learn: 0.1978227	total: 19s	remaining: 11.8s
# 617:	learn: 0.1976057	total: 19s	remaining: 11.8s
# 618:	learn: 0.1973952	total: 19.1s	remaining: 11.7s
# 619:	learn: 0.1971944	total: 19.1s	remaining: 11.7s
# 620:	learn: 0.1970166	total: 19.1s	remaining: 11.7s
# 621:	learn: 0.1968241	total: 19.2s	remaining: 11.6s
# 622:	learn: 0.1966927	total: 19.2s	remaining: 11.6s
# 623:	learn: 0.1964971	total: 19.2s	remaining: 11.6s
# 624:	learn: 0.1962991	total: 19.3s	remaining: 11.6s
# 625:	learn: 0.1961304	total: 19.3s	remaining: 11.5s
# 626:	learn: 0.1959507	total: 19.3s	remaining: 11.5s
# 627:	learn: 0.1958008	total: 19.4s	remaining: 11.5s
# 628:	learn: 0.1955843	total: 19.4s	remaining: 11.4s
# 629:	learn: 0.1954291	total: 19.4s	remaining: 11.4s
# 630:	learn: 0.1952960	total: 19.5s	remaining: 11.4s
# 631:	learn: 0.1951366	total: 19.5s	remaining: 11.3s
# 632:	learn: 0.1949836	total: 19.5s	remaining: 11.3s
# 633:	learn: 0.1948118	total: 19.5s	remaining: 11.3s
# 634:	learn: 0.1946471	total: 19.6s	remaining: 11.3s
# 635:	learn: 0.1944593	total: 19.6s	remaining: 11.2s
# 636:	learn: 0.1942866	total: 19.6s	remaining: 11.2s
# 637:	learn: 0.1941411	total: 19.7s	remaining: 11.2s
# 638:	learn: 0.1940094	total: 19.7s	remaining: 11.1s
# 639:	learn: 0.1938468	total: 19.7s	remaining: 11.1s
# 640:	learn: 0.1936610	total: 19.7s	remaining: 11.1s
# 641:	learn: 0.1934839	total: 19.8s	remaining: 11s
# 642:	learn: 0.1933259	total: 19.8s	remaining: 11s
# 643:	learn: 0.1931321	total: 19.8s	remaining: 11s
# 644:	learn: 0.1929765	total: 19.9s	remaining: 10.9s
# 645:	learn: 0.1928170	total: 19.9s	remaining: 10.9s
# 646:	learn: 0.1926221	total: 19.9s	remaining: 10.9s
# 647:	learn: 0.1924987	total: 20s	remaining: 10.8s
# 648:	learn: 0.1922969	total: 20s	remaining: 10.8s
# 649:	learn: 0.1921586	total: 20s	remaining: 10.8s
# 650:	learn: 0.1919672	total: 20.1s	remaining: 10.8s
# 651:	learn: 0.1918542	total: 20.1s	remaining: 10.7s
# 652:	learn: 0.1916992	total: 20.1s	remaining: 10.7s
# 653:	learn: 0.1915562	total: 20.1s	remaining: 10.7s
# 654:	learn: 0.1914268	total: 20.2s	remaining: 10.6s
# 655:	learn: 0.1912798	total: 20.2s	remaining: 10.6s
# 656:	learn: 0.1911052	total: 20.2s	remaining: 10.6s
# 657:	learn: 0.1909530	total: 20.3s	remaining: 10.5s
# 658:	learn: 0.1908364	total: 20.3s	remaining: 10.5s
# 659:	learn: 0.1907040	total: 20.3s	remaining: 10.5s
# 660:	learn: 0.1905741	total: 20.4s	remaining: 10.4s
# 661:	learn: 0.1904104	total: 20.4s	remaining: 10.4s
# 662:	learn: 0.1902540	total: 20.4s	remaining: 10.4s
# 663:	learn: 0.1901550	total: 20.5s	remaining: 10.4s
# 664:	learn: 0.1900084	total: 20.5s	remaining: 10.3s
# 665:	learn: 0.1898377	total: 20.5s	remaining: 10.3s
# 666:	learn: 0.1896921	total: 20.6s	remaining: 10.3s
# 667:	learn: 0.1895175	total: 20.6s	remaining: 10.2s
# 668:	learn: 0.1893843	total: 20.6s	remaining: 10.2s
# 669:	learn: 0.1892390	total: 20.7s	remaining: 10.2s
# 670:	learn: 0.1890723	total: 20.7s	remaining: 10.1s
# 671:	learn: 0.1889237	total: 20.7s	remaining: 10.1s
# 672:	learn: 0.1887938	total: 20.8s	remaining: 10.1s
# 673:	learn: 0.1886890	total: 20.8s	remaining: 10.1s
# 674:	learn: 0.1885586	total: 20.8s	remaining: 10s
# 675:	learn: 0.1883831	total: 20.9s	remaining: 10s
# 676:	learn: 0.1882519	total: 20.9s	remaining: 9.97s
# 677:	learn: 0.1881577	total: 20.9s	remaining: 9.94s
# 678:	learn: 0.1879894	total: 21s	remaining: 9.91s
# 679:	learn: 0.1878267	total: 21s	remaining: 9.88s
# 680:	learn: 0.1876830	total: 21s	remaining: 9.85s
# 681:	learn: 0.1875189	total: 21.1s	remaining: 9.82s
# 682:	learn: 0.1873654	total: 21.1s	remaining: 9.79s
# 683:	learn: 0.1872058	total: 21.1s	remaining: 9.76s
# 684:	learn: 0.1870341	total: 21.2s	remaining: 9.73s
# 685:	learn: 0.1868396	total: 21.2s	remaining: 9.7s
# 686:	learn: 0.1866979	total: 21.2s	remaining: 9.67s
# 687:	learn: 0.1865780	total: 21.3s	remaining: 9.64s
# 688:	learn: 0.1863846	total: 21.3s	remaining: 9.61s
# 689:	learn: 0.1862336	total: 21.3s	remaining: 9.58s
# 690:	learn: 0.1860883	total: 21.3s	remaining: 9.54s
# 691:	learn: 0.1859136	total: 21.4s	remaining: 9.51s
# 692:	learn: 0.1857486	total: 21.4s	remaining: 9.48s
# 693:	learn: 0.1855995	total: 21.4s	remaining: 9.45s
# 694:	learn: 0.1854649	total: 21.5s	remaining: 9.42s
# 695:	learn: 0.1853314	total: 21.5s	remaining: 9.39s
# 696:	learn: 0.1852117	total: 21.5s	remaining: 9.36s
# 697:	learn: 0.1850903	total: 21.5s	remaining: 9.32s
# 698:	learn: 0.1849089	total: 21.6s	remaining: 9.29s
# 699:	learn: 0.1847733	total: 21.6s	remaining: 9.26s
# 700:	learn: 0.1846328	total: 21.6s	remaining: 9.23s
# 701:	learn: 0.1844883	total: 21.7s	remaining: 9.2s
# 702:	learn: 0.1843472	total: 21.7s	remaining: 9.17s
# 703:	learn: 0.1841583	total: 21.7s	remaining: 9.14s
# 704:	learn: 0.1839940	total: 21.8s	remaining: 9.11s
# 705:	learn: 0.1838773	total: 21.8s	remaining: 9.08s
# 706:	learn: 0.1837032	total: 21.8s	remaining: 9.05s
# 707:	learn: 0.1835706	total: 21.9s	remaining: 9.02s
# 708:	learn: 0.1833955	total: 21.9s	remaining: 8.98s
# 709:	learn: 0.1832618	total: 21.9s	remaining: 8.95s
# 710:	learn: 0.1831317	total: 22s	remaining: 8.92s
# 711:	learn: 0.1829615	total: 22s	remaining: 8.89s
# 712:	learn: 0.1828352	total: 22s	remaining: 8.87s
# 713:	learn: 0.1827094	total: 22.1s	remaining: 8.84s
# 714:	learn: 0.1826028	total: 22.1s	remaining: 8.81s
# 715:	learn: 0.1824606	total: 22.1s	remaining: 8.77s
# 716:	learn: 0.1823048	total: 22.1s	remaining: 8.74s
# 717:	learn: 0.1821745	total: 22.2s	remaining: 8.71s
# 718:	learn: 0.1820333	total: 22.2s	remaining: 8.68s
# 719:	learn: 0.1818992	total: 22.2s	remaining: 8.65s
# 720:	learn: 0.1818297	total: 22.3s	remaining: 8.62s
# 721:	learn: 0.1816857	total: 22.3s	remaining: 8.59s
# 722:	learn: 0.1814910	total: 22.3s	remaining: 8.56s
# 723:	learn: 0.1813455	total: 22.4s	remaining: 8.53s
# 724:	learn: 0.1812056	total: 22.4s	remaining: 8.49s
# 725:	learn: 0.1811176	total: 22.4s	remaining: 8.46s
# 726:	learn: 0.1809203	total: 22.5s	remaining: 8.43s
# 727:	learn: 0.1807514	total: 22.5s	remaining: 8.4s
# 728:	learn: 0.1805682	total: 22.5s	remaining: 8.37s
# 729:	learn: 0.1803929	total: 22.5s	remaining: 8.34s
# 730:	learn: 0.1802827	total: 22.6s	remaining: 8.31s
# 731:	learn: 0.1801156	total: 22.6s	remaining: 8.28s
# 732:	learn: 0.1799017	total: 22.6s	remaining: 8.24s
# 733:	learn: 0.1797459	total: 22.7s	remaining: 8.21s
# 734:	learn: 0.1796606	total: 22.7s	remaining: 8.18s
# 735:	learn: 0.1794878	total: 22.7s	remaining: 8.15s
# 736:	learn: 0.1793604	total: 22.7s	remaining: 8.12s
# 737:	learn: 0.1792273	total: 22.8s	remaining: 8.09s
# 738:	learn: 0.1790578	total: 22.8s	remaining: 8.05s
# 739:	learn: 0.1789173	total: 22.8s	remaining: 8.02s
# 740:	learn: 0.1787782	total: 22.9s	remaining: 7.99s
# 741:	learn: 0.1786495	total: 22.9s	remaining: 7.96s
# 742:	learn: 0.1784512	total: 22.9s	remaining: 7.93s
# 743:	learn: 0.1783111	total: 23s	remaining: 7.9s
# 744:	learn: 0.1781502	total: 23s	remaining: 7.87s
# 745:	learn: 0.1779784	total: 23s	remaining: 7.84s
# 746:	learn: 0.1778376	total: 23.1s	remaining: 7.81s
# 747:	learn: 0.1776971	total: 23.1s	remaining: 7.78s
# 748:	learn: 0.1775803	total: 23.1s	remaining: 7.75s
# 749:	learn: 0.1774347	total: 23.1s	remaining: 7.72s
# 750:	learn: 0.1773356	total: 23.2s	remaining: 7.68s
# 751:	learn: 0.1772043	total: 23.2s	remaining: 7.66s
# 752:	learn: 0.1770736	total: 23.2s	remaining: 7.62s
# 753:	learn: 0.1769435	total: 23.3s	remaining: 7.59s
# 754:	learn: 0.1768341	total: 23.3s	remaining: 7.56s
# 755:	learn: 0.1767364	total: 23.3s	remaining: 7.53s
# 756:	learn: 0.1765332	total: 23.4s	remaining: 7.5s
# 757:	learn: 0.1764212	total: 23.4s	remaining: 7.47s
# 758:	learn: 0.1762977	total: 23.4s	remaining: 7.44s
# 759:	learn: 0.1761602	total: 23.5s	remaining: 7.41s
# 760:	learn: 0.1760129	total: 23.5s	remaining: 7.38s
# 761:	learn: 0.1758266	total: 23.6s	remaining: 7.36s
# 762:	learn: 0.1756653	total: 23.6s	remaining: 7.33s
# 763:	learn: 0.1755426	total: 23.6s	remaining: 7.29s
# 764:	learn: 0.1754172	total: 23.6s	remaining: 7.26s
# 765:	learn: 0.1752960	total: 23.7s	remaining: 7.23s
# 766:	learn: 0.1751691	total: 23.7s	remaining: 7.2s
# 767:	learn: 0.1750566	total: 23.7s	remaining: 7.17s
# 768:	learn: 0.1748897	total: 23.8s	remaining: 7.14s
# 769:	learn: 0.1747231	total: 23.8s	remaining: 7.11s
# 770:	learn: 0.1745628	total: 23.8s	remaining: 7.08s
# 771:	learn: 0.1743924	total: 23.9s	remaining: 7.05s
# 772:	learn: 0.1743027	total: 23.9s	remaining: 7.03s
# 773:	learn: 0.1741796	total: 24s	remaining: 7s
# 774:	learn: 0.1740230	total: 24s	remaining: 6.97s
# 775:	learn: 0.1739095	total: 24s	remaining: 6.93s
# 776:	learn: 0.1738168	total: 24.1s	remaining: 6.91s
# 777:	learn: 0.1736220	total: 24.1s	remaining: 6.87s
# 778:	learn: 0.1735244	total: 24.1s	remaining: 6.84s
# 779:	learn: 0.1733865	total: 24.2s	remaining: 6.81s
# 780:	learn: 0.1732624	total: 24.2s	remaining: 6.78s
# 781:	learn: 0.1731081	total: 24.2s	remaining: 6.75s
# 782:	learn: 0.1729291	total: 24.3s	remaining: 6.72s
# 783:	learn: 0.1728089	total: 24.3s	remaining: 6.7s
# 784:	learn: 0.1726676	total: 24.3s	remaining: 6.67s
# 785:	learn: 0.1725108	total: 24.4s	remaining: 6.64s
# 786:	learn: 0.1723592	total: 24.4s	remaining: 6.61s
# 787:	learn: 0.1722256	total: 24.4s	remaining: 6.58s
# 788:	learn: 0.1720548	total: 24.5s	remaining: 6.55s
# 789:	learn: 0.1719207	total: 24.5s	remaining: 6.52s
# 790:	learn: 0.1717884	total: 24.6s	remaining: 6.49s
# 791:	learn: 0.1716374	total: 24.6s	remaining: 6.46s
# 792:	learn: 0.1714770	total: 24.7s	remaining: 6.43s
# 793:	learn: 0.1713195	total: 24.7s	remaining: 6.4s
# 794:	learn: 0.1712058	total: 24.7s	remaining: 6.37s
# 795:	learn: 0.1710940	total: 24.7s	remaining: 6.34s
# 796:	learn: 0.1709802	total: 24.8s	remaining: 6.31s
# 797:	learn: 0.1708780	total: 24.8s	remaining: 6.28s
# 798:	learn: 0.1707291	total: 24.8s	remaining: 6.25s
# 799:	learn: 0.1706257	total: 24.9s	remaining: 6.22s
# 800:	learn: 0.1705307	total: 24.9s	remaining: 6.19s
# 801:	learn: 0.1703930	total: 24.9s	remaining: 6.16s
# 802:	learn: 0.1702484	total: 25s	remaining: 6.13s
# 803:	learn: 0.1701534	total: 25s	remaining: 6.09s
# 804:	learn: 0.1700429	total: 25s	remaining: 6.06s
# 805:	learn: 0.1699337	total: 25.1s	remaining: 6.03s
# 806:	learn: 0.1698150	total: 25.1s	remaining: 6s
# 807:	learn: 0.1696846	total: 25.1s	remaining: 5.97s
# 808:	learn: 0.1695484	total: 25.2s	remaining: 5.94s
# 809:	learn: 0.1694126	total: 25.2s	remaining: 5.91s
# 810:	learn: 0.1693000	total: 25.2s	remaining: 5.88s
# 811:	learn: 0.1691723	total: 25.3s	remaining: 5.85s
# 812:	learn: 0.1690106	total: 25.3s	remaining: 5.82s
# 813:	learn: 0.1689091	total: 25.3s	remaining: 5.79s
# 814:	learn: 0.1687665	total: 25.4s	remaining: 5.76s
# 815:	learn: 0.1686206	total: 25.4s	remaining: 5.73s
# 816:	learn: 0.1685069	total: 25.4s	remaining: 5.7s
# 817:	learn: 0.1684220	total: 25.5s	remaining: 5.67s
# 818:	learn: 0.1682932	total: 25.5s	remaining: 5.63s
# 819:	learn: 0.1681532	total: 25.5s	remaining: 5.6s
# 820:	learn: 0.1679931	total: 25.6s	remaining: 5.57s
# 821:	learn: 0.1678757	total: 25.6s	remaining: 5.54s
# 822:	learn: 0.1677639	total: 25.6s	remaining: 5.51s
# 823:	learn: 0.1676661	total: 25.6s	remaining: 5.48s
# 824:	learn: 0.1674979	total: 25.7s	remaining: 5.45s
# 825:	learn: 0.1673322	total: 25.7s	remaining: 5.42s
# 826:	learn: 0.1672589	total: 25.7s	remaining: 5.38s
# 827:	learn: 0.1671008	total: 25.8s	remaining: 5.35s
# 828:	learn: 0.1670163	total: 25.8s	remaining: 5.32s
# 829:	learn: 0.1668644	total: 25.8s	remaining: 5.29s
# 830:	learn: 0.1667466	total: 25.9s	remaining: 5.26s
# 831:	learn: 0.1666441	total: 25.9s	remaining: 5.23s
# 832:	learn: 0.1665462	total: 25.9s	remaining: 5.2s
# 833:	learn: 0.1664598	total: 26s	remaining: 5.17s
# 834:	learn: 0.1662929	total: 26s	remaining: 5.14s
# 835:	learn: 0.1661574	total: 26s	remaining: 5.11s
# 836:	learn: 0.1659942	total: 26.1s	remaining: 5.08s
# 837:	learn: 0.1658547	total: 26.1s	remaining: 5.04s
# 838:	learn: 0.1656798	total: 26.1s	remaining: 5.01s
# 839:	learn: 0.1655846	total: 26.2s	remaining: 4.98s
# 840:	learn: 0.1655018	total: 26.2s	remaining: 4.95s
# 841:	learn: 0.1653427	total: 26.2s	remaining: 4.92s
# 842:	learn: 0.1652280	total: 26.3s	remaining: 4.89s
# 843:	learn: 0.1650931	total: 26.3s	remaining: 4.86s
# 844:	learn: 0.1649943	total: 26.3s	remaining: 4.83s
# 845:	learn: 0.1648663	total: 26.4s	remaining: 4.8s
# 846:	learn: 0.1647385	total: 26.4s	remaining: 4.77s
# 847:	learn: 0.1645523	total: 26.4s	remaining: 4.74s
# 848:	learn: 0.1644423	total: 26.5s	remaining: 4.71s
# 849:	learn: 0.1643895	total: 26.5s	remaining: 4.67s
# 850:	learn: 0.1642674	total: 26.5s	remaining: 4.64s
# 851:	learn: 0.1641686	total: 26.6s	remaining: 4.61s
# 852:	learn: 0.1640451	total: 26.6s	remaining: 4.58s
# 853:	learn: 0.1639528	total: 26.6s	remaining: 4.55s
# 854:	learn: 0.1637925	total: 26.6s	remaining: 4.52s
# 855:	learn: 0.1637011	total: 26.7s	remaining: 4.49s
# 856:	learn: 0.1635906	total: 26.7s	remaining: 4.46s
# 857:	learn: 0.1634514	total: 26.7s	remaining: 4.42s
# 858:	learn: 0.1633665	total: 26.8s	remaining: 4.39s
# 859:	learn: 0.1632452	total: 26.8s	remaining: 4.36s
# 860:	learn: 0.1630929	total: 26.8s	remaining: 4.33s
# 861:	learn: 0.1629866	total: 26.9s	remaining: 4.3s
# 862:	learn: 0.1628611	total: 26.9s	remaining: 4.27s
# 863:	learn: 0.1627326	total: 26.9s	remaining: 4.24s
# 864:	learn: 0.1626084	total: 27s	remaining: 4.21s
# 865:	learn: 0.1624797	total: 27s	remaining: 4.18s
# 866:	learn: 0.1623809	total: 27s	remaining: 4.14s
# 867:	learn: 0.1622572	total: 27.1s	remaining: 4.11s
# 868:	learn: 0.1621306	total: 27.1s	remaining: 4.08s
# 869:	learn: 0.1620048	total: 27.1s	remaining: 4.05s
# 870:	learn: 0.1618718	total: 27.2s	remaining: 4.02s
# 871:	learn: 0.1617748	total: 27.2s	remaining: 3.99s
# 872:	learn: 0.1615898	total: 27.2s	remaining: 3.96s
# 873:	learn: 0.1614535	total: 27.3s	remaining: 3.93s
# 874:	learn: 0.1613509	total: 27.3s	remaining: 3.9s
# 875:	learn: 0.1611712	total: 27.3s	remaining: 3.87s
# 876:	learn: 0.1610247	total: 27.3s	remaining: 3.83s
# 877:	learn: 0.1608887	total: 27.4s	remaining: 3.8s
# 878:	learn: 0.1607497	total: 27.4s	remaining: 3.77s
# 879:	learn: 0.1606865	total: 27.4s	remaining: 3.74s
# 880:	learn: 0.1605577	total: 27.5s	remaining: 3.71s
# 881:	learn: 0.1604718	total: 27.5s	remaining: 3.68s
# 882:	learn: 0.1603189	total: 27.5s	remaining: 3.65s
# 883:	learn: 0.1602196	total: 27.6s	remaining: 3.62s
# 884:	learn: 0.1601371	total: 27.6s	remaining: 3.59s
# 885:	learn: 0.1599947	total: 27.6s	remaining: 3.56s
# 886:	learn: 0.1598766	total: 27.7s	remaining: 3.52s
# 887:	learn: 0.1597716	total: 27.7s	remaining: 3.49s
# 888:	learn: 0.1596492	total: 27.7s	remaining: 3.46s
# 889:	learn: 0.1595294	total: 27.8s	remaining: 3.43s
# 890:	learn: 0.1594327	total: 27.8s	remaining: 3.4s
# 891:	learn: 0.1592510	total: 27.8s	remaining: 3.37s
# 892:	learn: 0.1592008	total: 27.9s	remaining: 3.34s
# 893:	learn: 0.1590726	total: 27.9s	remaining: 3.31s
# 894:	learn: 0.1589310	total: 27.9s	remaining: 3.27s
# 895:	learn: 0.1588456	total: 27.9s	remaining: 3.24s
# 896:	learn: 0.1587105	total: 28s	remaining: 3.21s
# 897:	learn: 0.1585481	total: 28s	remaining: 3.18s
# 898:	learn: 0.1584285	total: 28s	remaining: 3.15s
# 899:	learn: 0.1583246	total: 28.1s	remaining: 3.12s
# 900:	learn: 0.1582369	total: 28.1s	remaining: 3.09s
# 901:	learn: 0.1580834	total: 28.1s	remaining: 3.06s
# 902:	learn: 0.1579804	total: 28.2s	remaining: 3.03s
# 903:	learn: 0.1578690	total: 28.2s	remaining: 3s
# 904:	learn: 0.1577452	total: 28.2s	remaining: 2.96s
# 905:	learn: 0.1576195	total: 28.3s	remaining: 2.93s
# 906:	learn: 0.1574658	total: 28.3s	remaining: 2.9s
# 907:	learn: 0.1573399	total: 28.3s	remaining: 2.87s
# 908:	learn: 0.1571944	total: 28.4s	remaining: 2.84s
# 909:	learn: 0.1570944	total: 28.4s	remaining: 2.81s
# 910:	learn: 0.1569633	total: 28.4s	remaining: 2.78s
# 911:	learn: 0.1568597	total: 28.5s	remaining: 2.75s
# ...
# 691:	learn: 0.2113216	total: 22.1s	remaining: 9.83s
# 692:	learn: 0.2112028	total: 22.1s	remaining: 9.8s
# 693:	learn: 0.2110617	total: 22.1s	remaining: 9.76s
# 694:	learn: 0.2108692	total: 22.2s	remaining: 9.73s
# 695:	learn: 0.2107239	total: 22.2s	remaining: 9.7s
# 696:	learn: 0.2105774	total: 22.2s	remaining: 9.66s
# 697:	learn: 0.2103874	total: 22.3s	remaining: 9.63s
# 698:	learn: 0.2102485	total: 22.3s	remaining: 9.6s
# 699:	learn: 0.2100559	total: 22.3s	remaining: 9.57s
# 700:	learn: 0.2098506	total: 22.4s	remaining: 9.54s
# 701:	learn: 0.2096647	total: 22.4s	remaining: 9.51s
# 702:	learn: 0.2095288	total: 22.4s	remaining: 9.47s
# 703:	learn: 0.2094107	total: 22.5s	remaining: 9.44s
# 704:	learn: 0.2092592	total: 22.5s	remaining: 9.41s
# 705:	learn: 0.2091088	total: 22.5s	remaining: 9.38s
# 706:	learn: 0.2088796	total: 22.5s	remaining: 9.34s
# 707:	learn: 0.2087418	total: 22.6s	remaining: 9.31s
# 708:	learn: 0.2085890	total: 22.6s	remaining: 9.28s
# 709:	learn: 0.2083974	total: 22.6s	remaining: 9.24s
# 710:	learn: 0.2082252	total: 22.7s	remaining: 9.21s
# 711:	learn: 0.2080469	total: 22.7s	remaining: 9.18s
# 712:	learn: 0.2078682	total: 22.7s	remaining: 9.15s
# 713:	learn: 0.2077012	total: 22.8s	remaining: 9.12s
# 714:	learn: 0.2075387	total: 22.8s	remaining: 9.08s
# 715:	learn: 0.2073997	total: 22.8s	remaining: 9.05s
# 716:	learn: 0.2072629	total: 22.8s	remaining: 9.02s
# 717:	learn: 0.2071327	total: 22.9s	remaining: 8.98s
# 718:	learn: 0.2069665	total: 22.9s	remaining: 8.95s
# 719:	learn: 0.2068019	total: 22.9s	remaining: 8.91s
# 720:	learn: 0.2066626	total: 23s	remaining: 8.88s
# 721:	learn: 0.2064596	total: 23s	remaining: 8.85s
# 722:	learn: 0.2062811	total: 23s	remaining: 8.82s
# 723:	learn: 0.2061019	total: 23s	remaining: 8.78s
# 724:	learn: 0.2059471	total: 23.1s	remaining: 8.75s
# 725:	learn: 0.2058220	total: 23.1s	remaining: 8.72s
# 726:	learn: 0.2056332	total: 23.1s	remaining: 8.68s
# 727:	learn: 0.2054983	total: 23.2s	remaining: 8.65s
# 728:	learn: 0.2053417	total: 23.2s	remaining: 8.62s
# 729:	learn: 0.2051665	total: 23.2s	remaining: 8.59s
# 730:	learn: 0.2050470	total: 23.2s	remaining: 8.55s
# 731:	learn: 0.2048971	total: 23.3s	remaining: 8.52s
# 732:	learn: 0.2047470	total: 23.3s	remaining: 8.49s
# 733:	learn: 0.2045262	total: 23.3s	remaining: 8.46s
# 734:	learn: 0.2043701	total: 23.4s	remaining: 8.42s
# 735:	learn: 0.2041810	total: 23.4s	remaining: 8.39s
# 736:	learn: 0.2040738	total: 23.4s	remaining: 8.36s
# 737:	learn: 0.2039388	total: 23.5s	remaining: 8.33s
# 738:	learn: 0.2037176	total: 23.5s	remaining: 8.29s
# 739:	learn: 0.2035828	total: 23.5s	remaining: 8.26s
# 740:	learn: 0.2034226	total: 23.5s	remaining: 8.23s
# 741:	learn: 0.2032488	total: 23.6s	remaining: 8.2s
# 742:	learn: 0.2030706	total: 23.6s	remaining: 8.17s
# 743:	learn: 0.2029445	total: 23.6s	remaining: 8.14s
# 744:	learn: 0.2027709	total: 23.7s	remaining: 8.11s
# 745:	learn: 0.2025974	total: 23.7s	remaining: 8.08s
# 746:	learn: 0.2024711	total: 23.8s	remaining: 8.05s
# 747:	learn: 0.2023388	total: 23.8s	remaining: 8.02s
# 748:	learn: 0.2021692	total: 23.8s	remaining: 7.98s
# 749:	learn: 0.2020006	total: 23.9s	remaining: 7.95s
# 750:	learn: 0.2018359	total: 23.9s	remaining: 7.92s
# 751:	learn: 0.2016279	total: 23.9s	remaining: 7.89s
# 752:	learn: 0.2014544	total: 23.9s	remaining: 7.85s
# 753:	learn: 0.2013161	total: 24s	remaining: 7.82s
# 754:	learn: 0.2011478	total: 24s	remaining: 7.79s
# 755:	learn: 0.2010072	total: 24s	remaining: 7.75s
# 756:	learn: 0.2008631	total: 24.1s	remaining: 7.72s
# 757:	learn: 0.2006964	total: 24.1s	remaining: 7.69s
# 758:	learn: 0.2005608	total: 24.1s	remaining: 7.66s
# 759:	learn: 0.2004104	total: 24.1s	remaining: 7.63s
# 760:	learn: 0.2002571	total: 24.2s	remaining: 7.59s
# 761:	learn: 0.2000781	total: 24.2s	remaining: 7.56s
# 762:	learn: 0.1998926	total: 24.2s	remaining: 7.53s
# 763:	learn: 0.1997281	total: 24.3s	remaining: 7.5s
# 764:	learn: 0.1995598	total: 24.3s	remaining: 7.46s
# 765:	learn: 0.1994288	total: 24.3s	remaining: 7.43s
# 766:	learn: 0.1993299	total: 24.4s	remaining: 7.4s
# 767:	learn: 0.1992302	total: 24.4s	remaining: 7.37s
# 768:	learn: 0.1990847	total: 24.4s	remaining: 7.34s
# 769:	learn: 0.1989470	total: 24.5s	remaining: 7.3s
# 770:	learn: 0.1987882	total: 24.5s	remaining: 7.27s
# 771:	learn: 0.1986389	total: 24.5s	remaining: 7.24s
# 772:	learn: 0.1984809	total: 24.6s	remaining: 7.21s
# 773:	learn: 0.1983434	total: 24.6s	remaining: 7.18s
# 774:	learn: 0.1981956	total: 24.6s	remaining: 7.14s
# 775:	learn: 0.1980472	total: 24.6s	remaining: 7.11s
# 776:	learn: 0.1978973	total: 24.7s	remaining: 7.08s
# 777:	learn: 0.1976913	total: 24.7s	remaining: 7.05s
# 778:	learn: 0.1975174	total: 24.7s	remaining: 7.02s
# 779:	learn: 0.1973598	total: 24.8s	remaining: 6.99s
# 780:	learn: 0.1971585	total: 24.8s	remaining: 6.95s
# 781:	learn: 0.1970099	total: 24.8s	remaining: 6.92s
# 782:	learn: 0.1969232	total: 24.9s	remaining: 6.89s
# 783:	learn: 0.1967961	total: 24.9s	remaining: 6.86s
# 784:	learn: 0.1966766	total: 24.9s	remaining: 6.83s
# 785:	learn: 0.1964910	total: 24.9s	remaining: 6.79s
# 786:	learn: 0.1963602	total: 25s	remaining: 6.76s
# 787:	learn: 0.1961754	total: 25s	remaining: 6.73s
# 788:	learn: 0.1959976	total: 25s	remaining: 6.7s
# 789:	learn: 0.1958286	total: 25.1s	remaining: 6.66s
# 790:	learn: 0.1957004	total: 25.1s	remaining: 6.63s
# 791:	learn: 0.1955407	total: 25.1s	remaining: 6.6s
# 792:	learn: 0.1953971	total: 25.2s	remaining: 6.57s
# 793:	learn: 0.1952658	total: 25.2s	remaining: 6.53s
# 794:	learn: 0.1951218	total: 25.2s	remaining: 6.5s
# 795:	learn: 0.1950154	total: 25.2s	remaining: 6.47s
# 796:	learn: 0.1948982	total: 25.3s	remaining: 6.44s
# 797:	learn: 0.1947678	total: 25.3s	remaining: 6.41s
# 798:	learn: 0.1946151	total: 25.3s	remaining: 6.37s
# 799:	learn: 0.1945058	total: 25.4s	remaining: 6.34s
# 800:	learn: 0.1943055	total: 25.4s	remaining: 6.31s
# 801:	learn: 0.1941427	total: 25.4s	remaining: 6.28s
# 802:	learn: 0.1939705	total: 25.5s	remaining: 6.25s
# 803:	learn: 0.1938505	total: 25.5s	remaining: 6.21s
# 804:	learn: 0.1936969	total: 25.5s	remaining: 6.18s
# 805:	learn: 0.1935338	total: 25.6s	remaining: 6.15s
# 806:	learn: 0.1934182	total: 25.6s	remaining: 6.12s
# 807:	learn: 0.1932456	total: 25.6s	remaining: 6.09s
# 808:	learn: 0.1930767	total: 25.6s	remaining: 6.05s
# 809:	learn: 0.1929267	total: 25.7s	remaining: 6.02s
# 810:	learn: 0.1927855	total: 25.7s	remaining: 5.99s
# 811:	learn: 0.1926724	total: 25.7s	remaining: 5.96s
# 812:	learn: 0.1924865	total: 25.8s	remaining: 5.93s
# 813:	learn: 0.1923930	total: 25.8s	remaining: 5.89s
# 814:	learn: 0.1922459	total: 25.8s	remaining: 5.86s
# 815:	learn: 0.1921094	total: 25.8s	remaining: 5.83s
# 816:	learn: 0.1919781	total: 25.9s	remaining: 5.79s
# 817:	learn: 0.1918373	total: 25.9s	remaining: 5.76s
# 818:	learn: 0.1917024	total: 25.9s	remaining: 5.73s
# 819:	learn: 0.1915735	total: 26s	remaining: 5.7s
# 820:	learn: 0.1914623	total: 26s	remaining: 5.67s
# 821:	learn: 0.1912901	total: 26s	remaining: 5.64s
# 822:	learn: 0.1911336	total: 26.1s	remaining: 5.61s
# 823:	learn: 0.1909972	total: 26.1s	remaining: 5.58s
# 824:	learn: 0.1908469	total: 26.1s	remaining: 5.54s
# 825:	learn: 0.1907552	total: 26.2s	remaining: 5.51s
# 826:	learn: 0.1906161	total: 26.2s	remaining: 5.48s
# 827:	learn: 0.1904917	total: 26.2s	remaining: 5.45s
# 828:	learn: 0.1903397	total: 26.3s	remaining: 5.42s
# 829:	learn: 0.1901982	total: 26.3s	remaining: 5.38s
# 830:	learn: 0.1900813	total: 26.3s	remaining: 5.35s
# 831:	learn: 0.1899567	total: 26.4s	remaining: 5.32s
# 832:	learn: 0.1898387	total: 26.4s	remaining: 5.29s
# 833:	learn: 0.1896937	total: 26.4s	remaining: 5.26s
# 834:	learn: 0.1895856	total: 26.5s	remaining: 5.23s
# 835:	learn: 0.1894720	total: 26.5s	remaining: 5.2s
# 836:	learn: 0.1893259	total: 26.5s	remaining: 5.16s
# 837:	learn: 0.1891962	total: 26.5s	remaining: 5.13s
# 838:	learn: 0.1890513	total: 26.6s	remaining: 5.1s
# 839:	learn: 0.1888605	total: 26.6s	remaining: 5.07s
# 840:	learn: 0.1886914	total: 26.6s	remaining: 5.04s
# 841:	learn: 0.1885759	total: 26.7s	remaining: 5.01s
# 842:	learn: 0.1884281	total: 26.7s	remaining: 4.97s
# 843:	learn: 0.1882796	total: 26.7s	remaining: 4.94s
# 844:	learn: 0.1881553	total: 26.8s	remaining: 4.91s
# 845:	learn: 0.1879954	total: 26.8s	remaining: 4.88s
# 846:	learn: 0.1878472	total: 26.8s	remaining: 4.84s
# 847:	learn: 0.1877463	total: 26.9s	remaining: 4.81s
# 848:	learn: 0.1875931	total: 26.9s	remaining: 4.78s
# 849:	learn: 0.1874484	total: 26.9s	remaining: 4.75s
# 850:	learn: 0.1873098	total: 27s	remaining: 4.72s
# 851:	learn: 0.1871818	total: 27s	remaining: 4.69s
# 852:	learn: 0.1870242	total: 27s	remaining: 4.66s
# 853:	learn: 0.1868773	total: 27.1s	remaining: 4.63s
# 854:	learn: 0.1867637	total: 27.1s	remaining: 4.59s
# 855:	learn: 0.1866390	total: 27.1s	remaining: 4.56s
# 856:	learn: 0.1864927	total: 27.2s	remaining: 4.53s
# 857:	learn: 0.1863552	total: 27.2s	remaining: 4.5s
# 858:	learn: 0.1861954	total: 27.2s	remaining: 4.47s
# 859:	learn: 0.1860342	total: 27.3s	remaining: 4.44s
# 860:	learn: 0.1859403	total: 27.3s	remaining: 4.41s
# 861:	learn: 0.1857840	total: 27.3s	remaining: 4.38s
# 862:	learn: 0.1856599	total: 27.4s	remaining: 4.35s
# 863:	learn: 0.1854927	total: 27.4s	remaining: 4.31s
# 864:	learn: 0.1853692	total: 27.4s	remaining: 4.28s
# 865:	learn: 0.1852329	total: 27.5s	remaining: 4.25s
# 866:	learn: 0.1850594	total: 27.5s	remaining: 4.22s
# 867:	learn: 0.1849393	total: 27.5s	remaining: 4.19s
# 868:	learn: 0.1848373	total: 27.6s	remaining: 4.16s
# 869:	learn: 0.1846811	total: 27.6s	remaining: 4.13s
# 870:	learn: 0.1845800	total: 27.6s	remaining: 4.09s
# 871:	learn: 0.1844501	total: 27.7s	remaining: 4.06s
# 872:	learn: 0.1843520	total: 27.7s	remaining: 4.03s
# 873:	learn: 0.1842234	total: 27.7s	remaining: 4s
# 874:	learn: 0.1841129	total: 27.8s	remaining: 3.97s
# 875:	learn: 0.1840102	total: 27.8s	remaining: 3.93s
# 876:	learn: 0.1838770	total: 27.8s	remaining: 3.9s
# 877:	learn: 0.1837532	total: 27.9s	remaining: 3.87s
# 878:	learn: 0.1836278	total: 27.9s	remaining: 3.84s
# 879:	learn: 0.1834896	total: 27.9s	remaining: 3.81s
# 880:	learn: 0.1833828	total: 28s	remaining: 3.78s
# 881:	learn: 0.1832917	total: 28s	remaining: 3.74s
# 882:	learn: 0.1831358	total: 28s	remaining: 3.71s
# 883:	learn: 0.1830060	total: 28.1s	remaining: 3.68s
# 884:	learn: 0.1828725	total: 28.1s	remaining: 3.65s
# 885:	learn: 0.1827304	total: 28.1s	remaining: 3.62s
# 886:	learn: 0.1825819	total: 28.2s	remaining: 3.59s
# 887:	learn: 0.1824719	total: 28.2s	remaining: 3.55s
# 888:	learn: 0.1822893	total: 28.2s	remaining: 3.52s
# 889:	learn: 0.1821689	total: 28.2s	remaining: 3.49s
# 890:	learn: 0.1820621	total: 28.3s	remaining: 3.46s
# 891:	learn: 0.1819209	total: 28.3s	remaining: 3.43s
# 892:	learn: 0.1817493	total: 28.3s	remaining: 3.4s
# 893:	learn: 0.1815817	total: 28.4s	remaining: 3.36s
# 894:	learn: 0.1814632	total: 28.4s	remaining: 3.33s
# 895:	learn: 0.1813543	total: 28.4s	remaining: 3.3s
# 896:	learn: 0.1812470	total: 28.5s	remaining: 3.27s
# 897:	learn: 0.1811396	total: 28.5s	remaining: 3.24s
# 898:	learn: 0.1810008	total: 28.5s	remaining: 3.21s
# 899:	learn: 0.1808688	total: 28.6s	remaining: 3.17s
# 900:	learn: 0.1807519	total: 28.6s	remaining: 3.14s
# 901:	learn: 0.1805903	total: 28.6s	remaining: 3.11s
# 902:	learn: 0.1804517	total: 28.7s	remaining: 3.08s
# 903:	learn: 0.1803068	total: 28.7s	remaining: 3.05s
# 904:	learn: 0.1801910	total: 28.8s	remaining: 3.02s
# 905:	learn: 0.1800565	total: 28.8s	remaining: 2.99s
# 906:	learn: 0.1799323	total: 28.8s	remaining: 2.96s
# 907:	learn: 0.1798455	total: 28.9s	remaining: 2.92s
# 908:	learn: 0.1797016	total: 28.9s	remaining: 2.89s
# 909:	learn: 0.1795889	total: 28.9s	remaining: 2.86s
# 910:	learn: 0.1795172	total: 28.9s	remaining: 2.83s
# 911:	learn: 0.1794204	total: 29s	remaining: 2.8s
# 912:	learn: 0.1793024	total: 29s	remaining: 2.76s
# 913:	learn: 0.1791558	total: 29.1s	remaining: 2.73s
# 914:	learn: 0.1790674	total: 29.1s	remaining: 2.7s
# 915:	learn: 0.1789114	total: 29.1s	remaining: 2.67s
# 916:	learn: 0.1787637	total: 29.1s	remaining: 2.64s
# 917:	learn: 0.1786796	total: 29.2s	remaining: 2.61s
# 918:	learn: 0.1785459	total: 29.2s	remaining: 2.58s
# 919:	learn: 0.1784204	total: 29.3s	remaining: 2.54s
# 920:	learn: 0.1782737	total: 29.3s	remaining: 2.51s
# 921:	learn: 0.1781205	total: 29.3s	remaining: 2.48s
# 922:	learn: 0.1779820	total: 29.4s	remaining: 2.45s
# 923:	learn: 0.1778691	total: 29.4s	remaining: 2.42s
# 924:	learn: 0.1777443	total: 29.4s	remaining: 2.38s
# 925:	learn: 0.1776061	total: 29.5s	remaining: 2.35s
# 926:	learn: 0.1774256	total: 29.5s	remaining: 2.32s
# 927:	learn: 0.1772436	total: 29.5s	remaining: 2.29s
# 928:	learn: 0.1771635	total: 29.5s	remaining: 2.26s
# 929:	learn: 0.1770238	total: 29.6s	remaining: 2.23s
# 930:	learn: 0.1768754	total: 29.6s	remaining: 2.19s
# 931:	learn: 0.1767201	total: 29.6s	remaining: 2.16s
# 932:	learn: 0.1765548	total: 29.7s	remaining: 2.13s
# 933:	learn: 0.1763845	total: 29.7s	remaining: 2.1s
# 934:	learn: 0.1762476	total: 29.7s	remaining: 2.07s
# 935:	learn: 0.1761337	total: 29.8s	remaining: 2.04s
# 936:	learn: 0.1759564	total: 29.8s	remaining: 2s
# 937:	learn: 0.1758691	total: 29.8s	remaining: 1.97s
# 938:	learn: 0.1757095	total: 29.9s	remaining: 1.94s
# 939:	learn: 0.1755655	total: 29.9s	remaining: 1.91s
# 940:	learn: 0.1753822	total: 29.9s	remaining: 1.88s
# 941:	learn: 0.1752385	total: 29.9s	remaining: 1.84s
# 942:	learn: 0.1751023	total: 30s	remaining: 1.81s
# 943:	learn: 0.1749877	total: 30s	remaining: 1.78s
# 944:	learn: 0.1747963	total: 30.1s	remaining: 1.75s
# 945:	learn: 0.1746634	total: 30.1s	remaining: 1.72s
# 946:	learn: 0.1745713	total: 30.1s	remaining: 1.69s
# 947:	learn: 0.1744585	total: 30.1s	remaining: 1.65s
# 948:	learn: 0.1743598	total: 30.2s	remaining: 1.62s
# 949:	learn: 0.1742149	total: 30.2s	remaining: 1.59s
# 950:	learn: 0.1741170	total: 30.2s	remaining: 1.56s
# 951:	learn: 0.1740045	total: 30.3s	remaining: 1.52s
# 952:	learn: 0.1738696	total: 30.3s	remaining: 1.49s
# 953:	learn: 0.1737406	total: 30.3s	remaining: 1.46s
# 954:	learn: 0.1736056	total: 30.4s	remaining: 1.43s
# 955:	learn: 0.1734896	total: 30.4s	remaining: 1.4s
# 956:	learn: 0.1733786	total: 30.4s	remaining: 1.37s
# 957:	learn: 0.1732515	total: 30.4s	remaining: 1.33s
# 958:	learn: 0.1731433	total: 30.5s	remaining: 1.3s
# 959:	learn: 0.1730272	total: 30.5s	remaining: 1.27s
# 960:	learn: 0.1729138	total: 30.5s	remaining: 1.24s
# 961:	learn: 0.1728468	total: 30.6s	remaining: 1.21s
# 962:	learn: 0.1726813	total: 30.6s	remaining: 1.18s
# 963:	learn: 0.1725801	total: 30.6s	remaining: 1.14s
# 964:	learn: 0.1724496	total: 30.7s	remaining: 1.11s
# 965:	learn: 0.1723403	total: 30.7s	remaining: 1.08s
# 966:	learn: 0.1722332	total: 30.7s	remaining: 1.05s
# 967:	learn: 0.1720503	total: 30.7s	remaining: 1.02s
# 968:	learn: 0.1719545	total: 30.8s	remaining: 985ms
# 969:	learn: 0.1718374	total: 30.8s	remaining: 953ms
# 970:	learn: 0.1717136	total: 30.8s	remaining: 921ms
# 971:	learn: 0.1716162	total: 30.9s	remaining: 889ms
# 972:	learn: 0.1714750	total: 30.9s	remaining: 857ms
# 973:	learn: 0.1713927	total: 30.9s	remaining: 825ms
# 974:	learn: 0.1712438	total: 30.9s	remaining: 793ms
# 975:	learn: 0.1711276	total: 31s	remaining: 762ms
# 976:	learn: 0.1709990	total: 31s	remaining: 730ms
# 977:	learn: 0.1709293	total: 31s	remaining: 698ms
# 978:	learn: 0.1708004	total: 31.1s	remaining: 667ms
# 979:	learn: 0.1706779	total: 31.1s	remaining: 635ms
# 980:	learn: 0.1705718	total: 31.1s	remaining: 603ms
# 981:	learn: 0.1704438	total: 31.2s	remaining: 571ms
# 982:	learn: 0.1703672	total: 31.2s	remaining: 539ms
# 983:	learn: 0.1702604	total: 31.2s	remaining: 508ms
# 984:	learn: 0.1701165	total: 31.3s	remaining: 476ms
# 985:	learn: 0.1699909	total: 31.3s	remaining: 444ms
# 986:	learn: 0.1698646	total: 31.3s	remaining: 413ms
# 987:	learn: 0.1697337	total: 31.4s	remaining: 381ms
# 988:	learn: 0.1696023	total: 31.4s	remaining: 349ms
# 989:	learn: 0.1695081	total: 31.4s	remaining: 318ms
# 990:	learn: 0.1693840	total: 31.5s	remaining: 286ms
# 991:	learn: 0.1692678	total: 31.5s	remaining: 254ms
# 992:	learn: 0.1691423	total: 31.5s	remaining: 222ms
# 993:	learn: 0.1690020	total: 31.6s	remaining: 190ms
# 994:	learn: 0.1688762	total: 31.6s	remaining: 159ms
# 995:	learn: 0.1687545	total: 31.6s	remaining: 127ms
# 996:	learn: 0.1686097	total: 31.6s	remaining: 95.2ms
# 997:	learn: 0.1684581	total: 31.7s	remaining: 63.5ms
# 998:	learn: 0.1683171	total: 31.7s	remaining: 31.7ms
# 999:	learn: 0.1681860	total: 31.7s	remaining: 0us

# %%
fin_scores
# Out:
# [0.6763546255963542,
#  0.6678023693602192,
#  0.6751688248064891,
#  0.684149937155015,
#  0.6589346920617668]

# %% [markdown]
# И, наконец, сабмит.

# %%
model = lightgbm.LGBMClassifier()
model.fit(features, target)

save_obj(model, 'lgbmclf')

# %%
onehottest = one_hot_groups(test_data)
feattest = get_features(test_data)
feattest = hstack([feattest, onehottest])
feattest = feattest.tocsr()

pred = model.predict(feattest)
pred.astype(int)
pred.shape
# Out:
#   0%|          | 0/180 [00:00<?, ?it/s]
# (16627,)

# %%
pred = model.predict(feattest)
pred.astype(int)
pred.shape
# Out:
# (16627,)

# %%
save_obj(feattest, 'feature_test')

# %%
test_data['target'] = pred
test_data.to_csv('../project_data/predictions/sub1.csv', index=False, columns=['pair_id', 'target'])
